# %% [markdown]
# # Artificial Intelligence Nanodegree
#
# ## Convolutional Neural Networks
#
# ## Project: Write an Algorithm for a Dog Identification App
#
# ---
#
# In this notebook, some template code has already been provided for you, and you will need to implement additional functionality to successfully complete this project. You will not need to modify the included code beyond what is requested. Sections that begin with **'(IMPLEMENTATION)'** in the header indicate that the following block of code will require additional functionality which you must provide. Instructions will be provided for each section, and the specifics of the implementation are marked in the code block with a 'TODO' statement. Please be sure to read the instructions carefully!
#
# > **Note**: Once you have completed all of the code implementations, you need to finalize your work by exporting the iPython Notebook as an HTML document. Before exporting the notebook to html, all of the code cells need to have been run so that reviewers can see the final implementation and output. You can then export the notebook by using the menu above and navigating to  \n",
#     "**File -> Download as -> HTML (.html)**. Include the finished document along with this notebook as your submission.
#
# In addition to implementing code, there will be questions that you must answer which relate to the project and your implementation. Each section where you will answer a question is preceded by a **'Question X'** header. Carefully read each question and provide thorough answers in the following text boxes that begin with **'Answer:'**. Your project submission will be evaluated based on your answers to each of the questions and the implementation you provide.
#
# >**Note:** Code and Markdown cells can be executed using the **Shift + Enter** keyboard shortcut.  Markdown cells can be edited by double-clicking the cell to enter edit mode.
#
# The rubric contains _optional_ "Stand Out Suggestions" for enhancing the project beyond the minimum requirements. If you decide to pursue the "Stand Out Suggestions", you should include the code in this IPython notebook.
#
#
#
# ---
# ### Why We're Here
#
# In this notebook, you will make the first steps towards developing an algorithm that could be used as part of a mobile or web app.  At the end of this project, your code will accept any user-supplied image as input.  If a dog is detected in the image, it will provide an estimate of the dog's breed.  If a human is detected, it will provide an estimate of the dog breed that is most resembling.  The image below displays potential sample output of your finished project (... but we expect that each student's algorithm will behave differently!).
#
# ![Sample Dog Output](images/sample_dog_output.png)
#
# In this real-world setting, you will need to piece together a series of models to perform different tasks; for instance, the algorithm that detects humans in an image will be different from the CNN that infers dog breed.  There are many points of possible failure, and no perfect algorithm exists.  Your imperfect solution will nonetheless create a fun user experience!
#
# ### The Road Ahead
#
# We break the notebook into separate steps.  Feel free to use the links below to navigate the notebook.
#
# * [Step 0](#step0): Import Datasets
# * [Step 1](#step1): Detect Humans
# * [Step 2](#step2): Detect Dogs
# * [Step 3](#step3): Create a CNN to Classify Dog Breeds (from Scratch)
# * [Step 4](#step4): Use a CNN to Classify Dog Breeds (using Transfer Learning)
# * [Step 5](#step5): Create a CNN to Classify Dog Breeds (using Transfer Learning)
# * [Step 6](#step6): Write your Algorithm
# * [Step 7](#step7): Test Your Algorithm
#
# ---
# <a id='step0'></a>
# ## Step 0: Import Datasets
#
# ### Import Dog Dataset
#
# In the code cell below, we import a dataset of dog images.  We populate a few variables through the use of the `load_files` function from the scikit-learn library:
# - `train_files`, `valid_files`, `test_files` - numpy arrays containing file paths to images
# - `train_targets`, `valid_targets`, `test_targets` - numpy arrays containing onehot-encoded classification labels
# - `dog_names` - list of string-valued dog breed names for translating labels

# %%
from sklearn.datasets import load_files       
from keras.utils import np_utils
import numpy as np
from glob import glob

# define function to load train, test, and validation datasets
def load_dataset(path):
    data = load_files(path)
    dog_files = np.array(data['filenames'])
    dog_targets = np_utils.to_categorical(np.array(data['target']), 133)
    return dog_files, dog_targets

# load train, test, and validation datasets
train_files, train_targets = load_dataset('/data/dog_images/train')
valid_files, valid_targets = load_dataset('/data/dog_images/valid')
test_files, test_targets = load_dataset('/data/dog_images/test')

# load list of dog names
dog_names = [item[27:-1] for item in sorted(glob("/data/dog_images/train/*/"))]

# print statistics about the dataset
print('There are %d total dog categories.' % len(dog_names))
print('There are %s total dog images.\n' % len(np.hstack([train_files, valid_files, test_files])))
print('There are %d training dog images.' % len(train_files))
print('There are %d validation dog images.' % len(valid_files))
print('There are %d test dog images.'% len(test_files))
# Out:
# There are 133 total dog categories.
# There are 8351 total dog images.
#
# There are 6680 training dog images.
# There are 835 validation dog images.
# There are 836 test dog images.

# %% [markdown]
# ### Import Human Dataset
#
# In the code cell below, we import a dataset of human images, where the file paths are stored in the numpy array `human_files`.

# %%
import random
random.seed(8675309)

# load filenames in shuffled human dataset
human_files = np.array(glob("/data/lfw/*/*"))
random.shuffle(human_files)

# print statistics about the dataset
print('There are %d total human images.' % len(human_files))
# Out:
# There are 13233 total human images.

# %% [markdown]
# ---
# <a id='step1'></a>
# ## Step 1: Detect Humans
#
# We use OpenCV's implementation of [Haar feature-based cascade classifiers](http://docs.opencv.org/trunk/d7/d8b/tutorial_py_face_detection.html) to detect human faces in images.  OpenCV provides many pre-trained face detectors, stored as XML files on [github](https://github.com/opencv/opencv/tree/master/data/haarcascades).  We have downloaded one of these detectors and stored it in the `haarcascades` directory.
#
# In the next code cell, we demonstrate how to use this detector to find human faces in a sample image.

# %%
import cv2                
import matplotlib.pyplot as plt                        
# %matplotlib inline                               

# extract pre-trained face detector
face_cascade = cv2.CascadeClassifier('haarcascades/haarcascade_frontalface_alt.xml')

# load color (BGR) image
img = cv2.imread(human_files[3])
# convert BGR image to grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# find faces in image
faces = face_cascade.detectMultiScale(gray)

# print number of faces detected in the image
print('Number of faces detected:', len(faces))

# get bounding box for each detected face
for (x,y,w,h) in faces:
    # add bounding box to color image
    cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    
# convert BGR image to RGB for plotting
cv_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# display the image, along with bounding box
plt.imshow(cv_rgb)
plt.show()
# Out:
# Number of faces detected: 1

# %% [markdown]
# Before using any of the face detectors, it is standard procedure to convert the images to grayscale.  The `detectMultiScale` function executes the classifier stored in `face_cascade` and takes the grayscale image as a parameter.
#
# In the above code, `faces` is a numpy array of detected faces, where each row corresponds to a detected face.  Each detected face is a 1D array with four entries that specifies the bounding box of the detected face.  The first two entries in the array (extracted in the above code as `x` and `y`) specify the horizontal and vertical positions of the top left corner of the bounding box.  The last two entries in the array (extracted here as `w` and `h`) specify the width and height of the box.
#
# ### Write a Human Face Detector
#
# We can use this procedure to write a function that returns `True` if a human face is detected in an image and `False` otherwise.  This function, aptly named `face_detector`, takes a string-valued file path to an image as input and appears in the code block below.

# %%
# returns "True" if face is detected in image stored at img_path
def face_detector(img_path):
    img = cv2.imread(img_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray)
    return len(faces) > 0

# %% [markdown]
# ### (IMPLEMENTATION) Assess the Human Face Detector
#
# __Question 1:__ Use the code cell below to test the performance of the `face_detector` function.
# - What percentage of the first 100 images in `human_files` have a detected human face?
# - What percentage of the first 100 images in `dog_files` have a detected human face?
#
# Ideally, we would like 100% of human images with a detected face and 0% of dog images with a detected face.  You will see that our algorithm falls short of this goal, but still gives acceptable performance.  We extract the file paths for the first 100 images from each of the datasets and store them in the numpy arrays `human_files_short` and `dog_files_short`.
#
# __Answer:__
# - What percentage of the first 100 images in `human_files` have a detected human face? <br/>
#   **The algorithm detected 100% of all human faces in the images with human faces.**
# - What percentage of the first 100 images in `dog_files` have a detected human face? <br/>
#   **In 89% of the dog images we've detected human faces.**

# %%
human_files_short = human_files[:100]
dog_files_short = train_files[:100]
# Do NOT modify the code above this line.

## Test the performance of the face_detector algorithm 
## on the images in human_files_short and dog_files_short.

human_files_detection_result = list(map(lambda file: (file,face_detector(file)), human_files_short))
dog_files_detection_result = list(map(lambda file: (file,face_detector(file)), dog_files_short))

human_files_with_faces = list(filter(lambda detection_result: detection_result[1], human_files_detection_result))
dog_files_with_faces = list(filter(lambda detection_result: detection_result[1] is False, dog_files_detection_result))
human_files_without_faces = list(filter(lambda detection_result: detection_result[1] is False, human_files_detection_result))

print(len(human_files_with_faces))
print(len(dog_files_with_faces))

_, ax1 = plt.subplots(3,3)

for i in range(9):
    if i < len(human_files_without_faces):
        ax1[i//3,i%3].imshow(plt.imread(human_files_without_faces[i][0]))
    ax1[i//3,i%3].axis('off')

_, ax2 = plt.subplots(3,3)

for i in range(9):
    if i < len(dog_files_with_faces):
        ax2[i//3,i%3].imshow(plt.imread(dog_files_with_faces[i][0]))
    ax2[i//3,i%3].axis('off')
# Out:
# 100
# 89

# %% [markdown]
# __Question 2:__ This algorithmic choice necessitates that we communicate to the user that we accept human images only when they provide a clear view of a face (otherwise, we risk having unneccessarily frustrated users!). In your opinion, is this a reasonable expectation to pose on the user? If not, can you think of a way to detect humans in images that does not necessitate an image with a clearly presented face?
#
# __Answer:__
# I think it's reasonable to expect from a user that they provide a clear view of a face. In general, the face detection algorithm seems to work quite well. People who will use this app will try to take a "clear" picture of a person anyway, so I don't think that it will become a major problem in practice.
#
#
# We suggest the face detector from OpenCV as a potential way to detect human images in your algorithm, but you are free to explore other approaches, especially approaches that make use of deep learning :).  Please use the code cell below to design and test your own face detection algorithm.  If you decide to pursue this _optional_ task, report performance on each of the datasets.

# %%
## (Optional) TODO: Report the performance of another  
## face detection algorithm on the LFW dataset
### Feel free to use as many code cells as needed.

# %% [markdown]
# ---
# <a id='step2'></a>
# ## Step 2: Detect Dogs
#
# In this section, we use a pre-trained [ResNet-50](http://ethereon.github.io/netscope/#/gist/db945b393d40bfa26006) model to detect dogs in images.  Our first line of code downloads the ResNet-50 model, along with weights that have been trained on [ImageNet](http://www.image-net.org/), a very large, very popular dataset used for image classification and other vision tasks.  ImageNet contains over 10 million URLs, each linking to an image containing an object from one of [1000 categories](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a).  Given an image, this pre-trained ResNet-50 model returns a prediction (derived from the available categories in ImageNet) for the object that is contained in the image.

# %%
from keras.applications.resnet50 import ResNet50

# define ResNet50 model
ResNet50_model = ResNet50(weights='imagenet')
# Out:
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.2/resnet50_weights_tf_dim_ordering_tf_kernels.h5
# 102858752/102853048 [==============================] - 1s 0us/step

# %% [markdown]
# ### Pre-process the Data
#
# When using TensorFlow as backend, Keras CNNs require a 4D array (which we'll also refer to as a 4D tensor) as input, with shape
#
# $$
# (\text{nb_samples}, \text{rows}, \text{columns}, \text{channels}),
# $$
#
# where `nb_samples` corresponds to the total number of images (or samples), and `rows`, `columns`, and `channels` correspond to the number of rows, columns, and channels for each image, respectively.
#
# The `path_to_tensor` function below takes a string-valued file path to a color image as input and returns a 4D tensor suitable for supplying to a Keras CNN.  The function first loads the image and resizes it to a square image that is $224 \times 224$ pixels.  Next, the image is converted to an array, which is then resized to a 4D tensor.  In this case, since we are working with color images, each image has three channels.  Likewise, since we are processing a single image (or sample), the returned tensor will always have shape
#
# $$
# (1, 224, 224, 3).
# $$
#
# The `paths_to_tensor` function takes a numpy array of string-valued image paths as input and returns a 4D tensor with shape
#
# $$
# (\text{nb_samples}, 224, 224, 3).
# $$
#
# Here, `nb_samples` is the number of samples, or number of images, in the supplied array of image paths.  It is best to think of `nb_samples` as the number of 3D tensors (where each 3D tensor corresponds to a different image) in your dataset!

# %%
from keras.preprocessing import image                  
from tqdm import tqdm

def path_to_tensor(img_path):
    # loads RGB image as PIL.Image.Image type
    img = image.load_img(img_path, target_size=(224, 224))
    # convert PIL.Image.Image type to 3D tensor with shape (224, 224, 3)
    x = image.img_to_array(img)
    # convert 3D tensor to 4D tensor with shape (1, 224, 224, 3) and return 4D tensor
    return np.expand_dims(x, axis=0)

def paths_to_tensor(img_paths):
    list_of_tensors = [path_to_tensor(img_path) for img_path in tqdm(img_paths)]
    return np.vstack(list_of_tensors)

# %% [markdown]
# ### Making Predictions with ResNet-50
#
# Getting the 4D tensor ready for ResNet-50, and for any other pre-trained model in Keras, requires some additional processing.  First, the RGB image is converted to BGR by reordering the channels.  All pre-trained models have the additional normalization step that the mean pixel (expressed in RGB as $[103.939, 116.779, 123.68]$ and calculated from all pixels in all images in ImageNet) must be subtracted from every pixel in each image.  This is implemented in the imported function `preprocess_input`.  If you're curious, you can check the code for `preprocess_input` [here](https://github.com/fchollet/keras/blob/master/keras/applications/imagenet_utils.py).
#
# Now that we have a way to format our image for supplying to ResNet-50, we are now ready to use the model to extract the predictions.  This is accomplished with the `predict` method, which returns an array whose $i$-th entry is the model's predicted probability that the image belongs to the $i$-th ImageNet category.  This is implemented in the `ResNet50_predict_labels` function below.
#
# By taking the argmax of the predicted probability vector, we obtain an integer corresponding to the model's predicted object class, which we can identify with an object category through the use of this [dictionary](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a).

# %%
from keras.applications.resnet50 import preprocess_input, decode_predictions

def ResNet50_predict_labels(img_path):
    # returns prediction vector for image located at img_path
    img = preprocess_input(path_to_tensor(img_path))
    return np.argmax(ResNet50_model.predict(img))

# %% [markdown]
# ### Write a Dog Detector
#
# While looking at the [dictionary](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a), you will notice that the categories corresponding to dogs appear in an uninterrupted sequence and correspond to dictionary keys 151-268, inclusive, to include all categories from `'Chihuahua'` to `'Mexican hairless'`.  Thus, in order to check to see if an image is predicted to contain a dog by the pre-trained ResNet-50 model, we need only check if the `ResNet50_predict_labels` function above returns a value between 151 and 268 (inclusive).
#
# We use these ideas to complete the `dog_detector` function below, which returns `True` if a dog is detected in an image (and `False` if not).

# %%
### returns "True" if a dog is detected in the image stored at img_path
def dog_detector(img_path):
    prediction = ResNet50_predict_labels(img_path)
    return ((prediction <= 268) & (prediction >= 151))

# %% [markdown]
# ### (IMPLEMENTATION) Assess the Dog Detector
#
# __Question 3:__ Use the code cell below to test the performance of your `dog_detector` function.
# - What percentage of the images in `human_files_short` have a detected dog?
# - What percentage of the images in `dog_files_short` have a detected dog?
#
# __Answer:__
# - What percentage of the images in `human_files_short` have a detected dog? <br/>
#   **0%**
# - What percentage of the images in `dog_files_short` have a detected dog? <br/>
#   **100%**

# %%
### Test the performance of the dog_detector function
### on the images in human_files_short and dog_files_short.

human_files_with_dogs = list(filter(lambda file: dog_detector(file), human_files_short))
dog_files_with_dogs = list(filter(lambda file: dog_detector(file), dog_files_short))

print("Human files with dogs: " + str(len(human_files_with_dogs)))
print("Dog files with dogs: "+ str(len(dog_files_with_dogs)))

_, ax = plt.subplots(3,3)

for i in range(9):
    if i < len(human_files_with_dogs):
        ax[i//3,i%3].imshow(plt.imread(human_files_with_dogs[i]))
    ax[i//3,i%3].axis('off')
# Out:
# Human files with dogs: 0
# Dog files with dogs: 100

# %% [markdown]
# ---
# <a id='step3'></a>
# ## Step 3: Create a CNN to Classify Dog Breeds (from Scratch)
#
# Now that we have functions for detecting humans and dogs in images, we need a way to predict breed from images.  In this step, you will create a CNN that classifies dog breeds.  You must create your CNN _from scratch_ (so, you can't use transfer learning _yet_!), and you must attain a test accuracy of at least 1%.  In Step 5 of this notebook, you will have the opportunity to use transfer learning to create a CNN that attains greatly improved accuracy.
#
# Be careful with adding too many trainable layers!  More parameters means longer training, which means you are more likely to need a GPU to accelerate the training process.  Thankfully, Keras provides a handy estimate of the time that each epoch is likely to take; you can extrapolate this estimate to figure out how long it will take for your algorithm to train.
#
# We mention that the task of assigning breed to dogs from images is considered exceptionally challenging.  To see why, consider that *even a human* would have great difficulty in distinguishing between a Brittany and a Welsh Springer Spaniel.
#
# Brittany | Welsh Springer Spaniel
# - | -
# <img src="images/Brittany_02625.jpg" width="100"> | <img src="images/Welsh_springer_spaniel_08203.jpg" width="200">
#
# It is not difficult to find other dog breed pairs with minimal inter-class variation (for instance, Curly-Coated Retrievers and American Water Spaniels).
#
# Curly-Coated Retriever | American Water Spaniel
# - | -
# <img src="images/Curly-coated_retriever_03896.jpg" width="200"> | <img src="images/American_water_spaniel_00648.jpg" width="200">
#
#
# Likewise, recall that labradors come in yellow, chocolate, and black.  Your vision-based algorithm will have to conquer this high intra-class variation to determine how to classify all of these different shades as the same breed.
#
# Yellow Labrador | Chocolate Labrador | Black Labrador
# - | -
# <img src="images/Labrador_retriever_06457.jpg" width="150"> | <img src="images/Labrador_retriever_06455.jpg" width="240"> | <img src="images/Labrador_retriever_06449.jpg" width="220">
#
# We also mention that random chance presents an exceptionally low bar: setting aside the fact that the classes are slightly imabalanced, a random guess will provide a correct answer roughly 1 in 133 times, which corresponds to an accuracy of less than 1%.
#
# Remember that the practice is far ahead of the theory in deep learning.  Experiment with many different architectures, and trust your intuition.  And, of course, have fun!
#
# ### Pre-process the Data
#
# We rescale the images by dividing every pixel in every image by 255.

# %%
from PIL import ImageFile                            
ImageFile.LOAD_TRUNCATED_IMAGES = True                 

# pre-process the data for Keras
train_tensors = paths_to_tensor(train_files).astype('float32')/255
valid_tensors = paths_to_tensor(valid_files).astype('float32')/255
test_tensors = paths_to_tensor(test_files).astype('float32')/255
# Out:
# 100%|██████████| 6680/6680 [01:13<00:00, 90.86it/s]
# 100%|██████████| 835/835 [00:08<00:00, 101.50it/s]
# 100%|██████████| 836/836 [00:08<00:00, 101.59it/s]

# %% [markdown]
# ### (IMPLEMENTATION) Model Architecture
#
# Create a CNN to classify dog breed.  At the end of your code cell block, summarize the layers of your model by executing the line:
#
#         model.summary()
#
# We have imported some Python modules to get you started, but feel free to import as many modules as you need.  If you end up getting stuck, here's a hint that specifies a model that trains relatively fast on CPU and attains >1% test accuracy in 5 epochs:
#
# ![Sample CNN](images/sample_cnn.png)
#
# __Question 4:__ Outline the steps you took to get to your final CNN architecture and your reasoning at each step.  If you chose to use the hinted architecture above, describe why you think that CNN architecture should work well for the image classification task.
#
# __Answer:__ <br/>
# I developed multiple CNNs which differ slightly in terms of the number of layers and filters.
# For the final classifier I've chosen model 4.
#
# It comprised of multiple convolutional layers each followed with a max pooling layer that reduce the dimensionality.
# Each convolutional layers is also followed by relu activation function to deal with the vanishing gradient problem.
# I've also added two dropout layer to reduce overfitting. <br/>
# One final dense layer is then used to perform the final classification. I employ a softmax activation to make sure that the probabilities sum up to 1 (since a dog can only belong to one breed).

# %%
from keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D
from keras.layers import Dropout, Flatten, Dense
from keras.models import Sequential


def model1():
    
    model = Sequential()

    model.add(Conv2D(filters=16, kernel_size=6, padding='same', activation='relu', input_shape=(224,224,3)))
    model.add(MaxPooling2D(pool_size=2, padding='same'))
    model.add(Conv2D(filters=32, kernel_size=3, padding='same', activation='relu'))
    model.add(MaxPooling2D(pool_size=2, padding='same'))
    model.add(Conv2D(filters=64, kernel_size=3, padding='same', activation='relu'))
    model.add(Flatten())
    model.add(Dense(133, activation='softmax'))
    
    return model

def model2():
    
    model = Sequential()

    model.add(Conv2D(filters=32, kernel_size=6, padding='same', activation='relu', input_shape=(224,224,3)))
    model.add(MaxPooling2D(pool_size=2, padding='same'))
    model.add(Conv2D(filters=64, kernel_size=3, padding='same', activation='relu'))
    model.add(MaxPooling2D(pool_size=2, padding='same'))
    model.add(Conv2D(filters=128, kernel_size=3, padding='same', activation='relu'))
    model.add(Flatten())
    model.add(Dense(133, activation='softmax'))
    
    return model

def model3():
    
    model = Sequential()

    model.add(Conv2D(filters=16, kernel_size=12, padding='same', activation='relu', input_shape=(224,224,3)))
    model.add(MaxPooling2D(pool_size=2, padding='same'))
    model.add(Conv2D(filters=32, kernel_size=6, padding='same', activation='relu'))
    model.add(MaxPooling2D(pool_size=2, padding='same'))
    model.add(Conv2D(filters=64, kernel_size=3, padding='same', activation='relu'))
    model.add(Flatten())
    model.add(Dense(133, activation='softmax'))
    
    return model

def model4():

    model = Sequential()

    model.add(Conv2D(filters=32, kernel_size=6, padding='same', activation='relu', input_shape=(224,224,3)))
    model.add(MaxPooling2D(pool_size=2, padding='same'))
    model.add(Dropout(0.2))
    model.add(Conv2D(filters=64, kernel_size=3, padding='same', activation='relu'))
    model.add(MaxPooling2D(pool_size=2, padding='same'))
    model.add(Dropout(0.2))
    model.add(Conv2D(filters=128, kernel_size=3, padding='same', activation='relu'))
    model.add(Flatten())
    model.add(Dense(133, activation='softmax'))
    
    return model

model_1 = model1()
model_2 = model2()
model_3 = model3()
model_4 = model4()
model_4_with_aug = model4()

# %% [markdown]
# ### Compile the Model

# %%
from keras import optimizers

rmsprop = optimizers.RMSprop(lr=0.0001)

model_1.compile(optimizer=rmsprop, loss='categorical_crossentropy', metrics=['accuracy'])
model_2.compile(optimizer=rmsprop, loss='categorical_crossentropy', metrics=['accuracy'])
model_3.compile(optimizer=rmsprop, loss='categorical_crossentropy', metrics=['accuracy'])
model_4.compile(optimizer=rmsprop, loss='categorical_crossentropy', metrics=['accuracy'])
model_4_with_aug.compile(optimizer=rmsprop, loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ### (IMPLEMENTATION) Train the Model
#
# Train your model in the code cell below.  Use model checkpointing to save the model that attains the best validation loss.
#
# You are welcome to [augment the training data](https://blog.keras.io/building-powerful-image-classification-models-using-very-little-data.html), but this is not a requirement.

# %%
epochs=5

# %%
from keras.callbacks import ModelCheckpoint

# %%
checkpointer1 = ModelCheckpoint(filepath='saved_models/model1.weights.best.from_scratch.hdf5', 
                               verbose=1, save_best_only=True)

history1 = model_1.fit(train_tensors, train_targets, 
                      validation_data=(valid_tensors, valid_targets), 
                      epochs=epochs, batch_size=20, callbacks=[checkpointer1], verbose=1)
# Out:
# Train on 6680 samples, validate on 835 samples
# Epoch 1/5
# 6660/6680 [============================>.] - ETA: 0s - loss: 4.5472 - acc: 0.0685Epoch 00001: val_loss improved from inf to 4.40903, saving model to saved_models/model1.weights.best.from_scratch.hdf5
# 6680/6680 [==============================] - 37s 5ms/step - loss: 4.5462 - acc: 0.0687 - val_loss: 4.4090 - val_acc: 0.0623
# Epoch 2/5
# 6660/6680 [============================>.] - ETA: 0s - loss: 2.8950 - acc: 0.3814Epoch 00002: val_loss did not improve
# 6680/6680 [==============================] - 35s 5ms/step - loss: 2.8956 - acc: 0.3811 - val_loss: 4.5485 - val_acc: 0.0862
# Epoch 3/5
# 6660/6680 [============================>.] - ETA: 0s - loss: 1.2083 - acc: 0.7383Epoch 00003: val_loss did not improve
# 6680/6680 [==============================] - 35s 5ms/step - loss: 1.2086 - acc: 0.7380 - val_loss: 5.5560 - val_acc: 0.0743
# Epoch 4/5
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.3789 - acc: 0.9197Epoch 00004: val_loss did not improve
# 6680/6680 [==============================] - 35s 5ms/step - loss: 0.3783 - acc: 0.9199 - val_loss: 6.6008 - val_acc: 0.0623
# Epoch 5/5
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.0984 - acc: 0.9782Epoch 00005: val_loss did not improve
# 6680/6680 [==============================] - 35s 5ms/step - loss: 0.0984 - acc: 0.9781 - val_loss: 7.5929 - val_acc: 0.0671

# %%
checkpointer2 = ModelCheckpoint(filepath='saved_models/model2.weights.best.from_scratch.hdf5', 
                               verbose=1, save_best_only=True)

history2 = model_2.fit(train_tensors, train_targets, 
                      validation_data=(valid_tensors, valid_targets), 
                      epochs=epochs, batch_size=20, callbacks=[checkpointer2], verbose=1)
# Out:
# Train on 6680 samples, validate on 835 samples
# Epoch 1/5
# 6660/6680 [============================>.] - ETA: 0s - loss: 4.7625 - acc: 0.0321Epoch 00001: val_loss improved from inf to 4.48400, saving model to saved_models/model2.weights.best.from_scratch.hdf5
# 6680/6680 [==============================] - 64s 10ms/step - loss: 4.7600 - acc: 0.0322 - val_loss: 4.4840 - val_acc: 0.0551
# Epoch 2/5
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.6368 - acc: 0.2119Epoch 00002: val_loss improved from 4.48400 to 4.32540, saving model to saved_models/model2.weights.best.from_scratch.hdf5
# 6680/6680 [==============================] - 64s 10ms/step - loss: 3.6379 - acc: 0.2118 - val_loss: 4.3254 - val_acc: 0.0910
# Epoch 3/5
# 6660/6680 [============================>.] - ETA: 0s - loss: 1.7293 - acc: 0.6135Epoch 00003: val_loss did not improve
# 6680/6680 [==============================] - 62s 9ms/step - loss: 1.7272 - acc: 0.6142 - val_loss: 5.3491 - val_acc: 0.0826
# Epoch 4/5
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.5423 - acc: 0.8782Epoch 00004: val_loss did not improve
# 6680/6680 [==============================] - 62s 9ms/step - loss: 0.5414 - acc: 0.8783 - val_loss: 6.7305 - val_acc: 0.0790
# Epoch 5/5
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.1372 - acc: 0.9674Epoch 00005: val_loss did not improve
# 6680/6680 [==============================] - 62s 9ms/step - loss: 0.1371 - acc: 0.9675 - val_loss: 7.6180 - val_acc: 0.0719

# %%
checkpointer3 = ModelCheckpoint(filepath='saved_models/model3.weights.best.from_scratch.hdf5', 
                               verbose=1, save_best_only=True)

history3 = model_3.fit(train_tensors, train_targets, 
                      validation_data=(valid_tensors, valid_targets), 
                      epochs=epochs, batch_size=20, callbacks=[checkpointer3], verbose=1)
# Out:
# Train on 6680 samples, validate on 835 samples
# Epoch 1/5
# 6660/6680 [============================>.] - ETA: 0s - loss: 4.8126 - acc: 0.0257Epoch 00001: val_loss improved from inf to 4.54509, saving model to saved_models/model3.weights.best.from_scratch.hdf5
# 6680/6680 [==============================] - 41s 6ms/step - loss: 4.8111 - acc: 0.0259 - val_loss: 4.5451 - val_acc: 0.0491
# Epoch 2/5
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.8030 - acc: 0.1686Epoch 00002: val_loss did not improve
# 6680/6680 [==============================] - 39s 6ms/step - loss: 3.8019 - acc: 0.1687 - val_loss: 4.6783 - val_acc: 0.0587
# Epoch 3/5
# 6660/6680 [============================>.] - ETA: 0s - loss: 2.0667 - acc: 0.5206Epoch 00003: val_loss did not improve
# 6680/6680 [==============================] - 39s 6ms/step - loss: 2.0673 - acc: 0.5205 - val_loss: 5.3204 - val_acc: 0.0743
# Epoch 4/5
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.8556 - acc: 0.7968Epoch 00004: val_loss did not improve
# 6680/6680 [==============================] - 39s 6ms/step - loss: 0.8548 - acc: 0.7972 - val_loss: 6.6361 - val_acc: 0.0707
# Epoch 5/5
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.2662 - acc: 0.9338Epoch 00005: val_loss did not improve
# 6680/6680 [==============================] - 39s 6ms/step - loss: 0.2661 - acc: 0.9338 - val_loss: 7.9965 - val_acc: 0.0635

# %%
checkpointer4 = ModelCheckpoint(filepath='saved_models/model4.weights.best.from_scratch.hdf5', 
                               verbose=1, save_best_only=True)

history4 = model_4.fit(train_tensors, train_targets, 
                      validation_data=(valid_tensors, valid_targets), 
                      epochs=epochs, batch_size=20, callbacks=[checkpointer4], verbose=1)
# Out:
# Train on 6680 samples, validate on 835 samples
# Epoch 1/5
# 6660/6680 [============================>.] - ETA: 0s - loss: 4.8720 - acc: 0.0188Epoch 00001: val_loss improved from inf to 4.69588, saving model to saved_models/model4.weights.best.from_scratch.hdf5
# 6680/6680 [==============================] - 68s 10ms/step - loss: 4.8717 - acc: 0.0187 - val_loss: 4.6959 - val_acc: 0.0431
# Epoch 2/5
# 6660/6680 [============================>.] - ETA: 0s - loss: 4.3434 - acc: 0.0736Epoch 00002: val_loss improved from 4.69588 to 4.37810, saving model to saved_models/model4.weights.best.from_scratch.hdf5
# 6680/6680 [==============================] - 66s 10ms/step - loss: 4.3432 - acc: 0.0738 - val_loss: 4.3781 - val_acc: 0.0683
# Epoch 3/5
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.5071 - acc: 0.2257Epoch 00003: val_loss did not improve
# 6680/6680 [==============================] - 64s 10ms/step - loss: 3.5098 - acc: 0.2254 - val_loss: 4.5524 - val_acc: 0.0778
# Epoch 4/5
# 6660/6680 [============================>.] - ETA: 0s - loss: 2.3452 - acc: 0.4712Epoch 00004: val_loss did not improve
# 6680/6680 [==============================] - 64s 10ms/step - loss: 2.3438 - acc: 0.4716 - val_loss: 5.1024 - val_acc: 0.0802
# Epoch 5/5
# 6660/6680 [============================>.] - ETA: 0s - loss: 1.3453 - acc: 0.6779Epoch 00005: val_loss did not improve
# 6680/6680 [==============================] - 64s 10ms/step - loss: 1.3471 - acc: 0.6775 - val_loss: 6.1293 - val_acc: 0.0743

# %%
from keras.preprocessing.image import ImageDataGenerator

# Let's try augmentation
datagen = ImageDataGenerator(
    featurewise_center=True,
    featurewise_std_normalization=True,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True)

# compute quantities required for featurewise normalization
# (std, mean, and principal components if ZCA whitening is applied)
datagen.fit(train_tensors)

checkpointer5 = ModelCheckpoint(filepath='saved_models/model4_with_aug.weights.best.from_scratch.hdf5', 
                               verbose=1, save_best_only=True)

# Fit model 4 with real-time data augmentation
history5 = model_4_with_aug.fit_generator(
    datagen.flow(train_tensors, train_targets, batch_size=20), 
    validation_data=(valid_tensors, valid_targets),
    callbacks=[checkpointer5], 
    steps_per_epoch=len(train_tensors)/20,
    epochs=epochs, verbose=1)
# Out:
# Epoch 1/5
# 333/334 [============================>.] - ETA: 0s - loss: 4.2789 - acc: 0.0769Epoch 00001: val_loss improved from inf to 4.88453, saving model to saved_models/model4_with_aug.weights.best.from_scratch.hdf5
# 334/334 [==============================] - 66s 197ms/step - loss: 4.2788 - acc: 0.0768 - val_loss: 4.8845 - val_acc: 0.0419
# Epoch 2/5
# 333/334 [============================>.] - ETA: 0s - loss: 4.2257 - acc: 0.0776Epoch 00002: val_loss did not improve
# 334/334 [==============================] - 64s 190ms/step - loss: 4.2250 - acc: 0.0777 - val_loss: 5.0101 - val_acc: 0.0443
# Epoch 3/5
# 333/334 [============================>.] - ETA: 0s - loss: 4.2297 - acc: 0.0758Epoch 00003: val_loss improved from 4.88453 to 4.81198, saving model to saved_models/model4_with_aug.weights.best.from_scratch.hdf5
# 334/334 [==============================] - 66s 197ms/step - loss: 4.2298 - acc: 0.0757 - val_loss: 4.8120 - val_acc: 0.0347
# Epoch 4/5
# 333/334 [============================>.] - ETA: 0s - loss: 4.2112 - acc: 0.0769Epoch 00004: val_loss did not improve
# 334/334 [==============================] - 64s 191ms/step - loss: 4.2104 - acc: 0.0766 - val_loss: 5.0381 - val_acc: 0.0323
# Epoch 5/5
# 333/334 [============================>.] - ETA: 0s - loss: 4.2167 - acc: 0.0715Epoch 00005: val_loss did not improve
# 334/334 [==============================] - 64s 191ms/step - loss: 4.2175 - acc: 0.0714 - val_loss: 5.0575 - val_acc: 0.0287

# %%
# Plot train accuracy
plt.plot(history1.history['acc'])
plt.plot(history2.history['acc'])
plt.plot(history3.history['acc'])
plt.plot(history4.history['acc'])
plt.plot(history5.history['acc'])
plt.title('Train Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Model 1 Train Acc', 
            'Model 2 Train Acc', 
            'Model 3 Train Acc',
            'Model 4 Train Acc',
            'Model 4 with Aug Train Acc'], loc='upper left')
plt.show()

# Plot validation accuracy
plt.plot(history1.history['val_acc'])
plt.plot(history2.history['val_acc'])
plt.plot(history3.history['val_acc'])
plt.plot(history4.history['val_acc'])
plt.plot(history5.history['val_acc'])
plt.title('Validation Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Model 1 Val Acc', 
            'Model 2 Val Acc',
            'Model 3 Val Acc',
            'Model 4 Val Acc',
            'Model 4 with Aug Val Acc'], loc='upper left')
plt.show()

# Plot validation loss
plt.plot(history1.history['val_loss'])
plt.plot(history2.history['val_loss'])
plt.plot(history3.history['val_loss'])
plt.plot(history4.history['val_loss'])
plt.plot(history5.history['val_loss'])
plt.title('Validation Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Model 1 Val Loss', 
            'Model 2 Val Loss',
            'Model 3 Val Loss',
            'Model 4 Val Loss',
            'Model 4 with Aug Val Loss'], loc='upper left')
plt.show()

# %% [markdown]
# ### Load the Model with the Best Validation Loss

# %%
# Choose model 4 since it has the best accuracy on the validation data
model = model_4
model.load_weights('saved_models/model4.weights.best.from_scratch.hdf5')

# %% [markdown]
# ### Test the Model
#
# Try out your model on the test dataset of dog images.  Ensure that your test accuracy is greater than 1%.

# %%
# get index of predicted dog breed for each image in test set
dog_breed_predictions = [np.argmax(model.predict(np.expand_dims(tensor, axis=0))) for tensor in test_tensors]

# report test accuracy
test_accuracy = 100*np.sum(np.array(dog_breed_predictions)==np.argmax(test_targets, axis=1))/len(dog_breed_predictions)
print('Test accuracy: %.4f%%' % test_accuracy)
# Out:
# Test accuracy: 6.6986%

# %% [markdown]
# ---
# <a id='step4'></a>
# ## Step 4: Use a CNN to Classify Dog Breeds
#
# To reduce training time without sacrificing accuracy, we show you how to train a CNN using transfer learning.  In the following step, you will get a chance to use transfer learning to train your own CNN.
#
# ### Obtain Bottleneck Features

# %%
bottleneck_features = np.load('/data/bottleneck_features/DogVGG16Data.npz')
train_VGG16 = bottleneck_features['train']
valid_VGG16 = bottleneck_features['valid']
test_VGG16 = bottleneck_features['test']

# %% [markdown]
# ### Model Architecture
#
# The model uses the the pre-trained VGG-16 model as a fixed feature extractor, where the last convolutional output of VGG-16 is fed as input to our model.  We only add a global average pooling layer and a fully connected layer, where the latter contains one node for each dog category and is equipped with a softmax.

# %%
from keras.layers import GlobalAveragePooling2D, Dense

VGG16_model = Sequential()
VGG16_model.add(GlobalAveragePooling2D(input_shape=train_VGG16.shape[1:]))
VGG16_model.add(Dense(133, activation='softmax'))

VGG16_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# global_average_pooling2d_5 ( (None, 512)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 133)               68229
# =================================================================
# Total params: 68,229
# Trainable params: 68,229
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Compile the Model

# %%
from keras import optimizers

rmsprop = optimizers.RMSprop(lr=0.0001)

VGG16_model.compile(loss='categorical_crossentropy', optimizer=rmsprop, metrics=['accuracy'])

# %% [markdown]
# ### Train the Model

# %%
checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.VGG16.hdf5', 
                               verbose=1, save_best_only=True)

VGG16_model.fit(train_VGG16, train_targets, 
          validation_data=(valid_VGG16, valid_targets),
          epochs=20, batch_size=20, callbacks=[checkpointer], verbose=1)
# Out:
# Train on 6680 samples, validate on 835 samples
# Epoch 1/20
# 6580/6680 [============================>.] - ETA: 0s - loss: 13.9618 - acc: 0.0239Epoch 00001: val_loss improved from inf to 13.52092, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 258us/step - loss: 13.9573 - acc: 0.0240 - val_loss: 13.5209 - val_acc: 0.0359
# Epoch 2/20
# 6560/6680 [============================>.] - ETA: 0s - loss: 12.5910 - acc: 0.0570Epoch 00002: val_loss improved from 13.52092 to 12.39777, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 243us/step - loss: 12.5776 - acc: 0.0572 - val_loss: 12.3978 - val_acc: 0.0539
# Epoch 3/20
# 6440/6680 [===========================>..] - ETA: 0s - loss: 11.3562 - acc: 0.1003Epoch 00003: val_loss improved from 12.39777 to 11.30685, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 243us/step - loss: 11.3463 - acc: 0.0999 - val_loss: 11.3069 - val_acc: 0.0898
# Epoch 4/20
# 6460/6680 [============================>.] - ETA: 0s - loss: 10.3268 - acc: 0.1461Epoch 00004: val_loss improved from 11.30685 to 10.45291, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 241us/step - loss: 10.3480 - acc: 0.1466 - val_loss: 10.4529 - val_acc: 0.1353
# Epoch 5/20
# 6440/6680 [===========================>..] - ETA: 0s - loss: 9.5919 - acc: 0.1879Epoch 00005: val_loss improved from 10.45291 to 9.78180, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 242us/step - loss: 9.5629 - acc: 0.1901 - val_loss: 9.7818 - val_acc: 0.1701
# Epoch 6/20
# 6640/6680 [============================>.] - ETA: 0s - loss: 8.9041 - acc: 0.2334Epoch 00006: val_loss improved from 9.78180 to 9.22712, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 242us/step - loss: 8.9082 - acc: 0.2328 - val_loss: 9.2271 - val_acc: 0.2024
# Epoch 7/20
# 6580/6680 [============================>.] - ETA: 0s - loss: 8.3679 - acc: 0.2774Epoch 00007: val_loss improved from 9.22712 to 8.77963, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 244us/step - loss: 8.3641 - acc: 0.2774 - val_loss: 8.7796 - val_acc: 0.2371
# Epoch 8/20
# 6660/6680 [============================>.] - ETA: 0s - loss: 7.9000 - acc: 0.3092Epoch 00008: val_loss improved from 8.77963 to 8.33271, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 244us/step - loss: 7.9029 - acc: 0.3088 - val_loss: 8.3327 - val_acc: 0.2623
# Epoch 9/20
# 6660/6680 [============================>.] - ETA: 0s - loss: 7.5090 - acc: 0.3422Epoch 00009: val_loss improved from 8.33271 to 7.95993, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 242us/step - loss: 7.5014 - acc: 0.3425 - val_loss: 7.9599 - val_acc: 0.2731
# Epoch 10/20
# 6440/6680 [===========================>..] - ETA: 0s - loss: 7.1991 - acc: 0.3734Epoch 00010: val_loss improved from 7.95993 to 7.67535, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 243us/step - loss: 7.1883 - acc: 0.3747 - val_loss: 7.6754 - val_acc: 0.3054
# Epoch 11/20
# 6560/6680 [============================>.] - ETA: 0s - loss: 6.9409 - acc: 0.4055Epoch 00011: val_loss improved from 7.67535 to 7.49321, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 243us/step - loss: 6.9424 - acc: 0.4049 - val_loss: 7.4932 - val_acc: 0.3222
# Epoch 12/20
# 6660/6680 [============================>.] - ETA: 0s - loss: 6.7489 - acc: 0.4267Epoch 00012: val_loss improved from 7.49321 to 7.27997, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 243us/step - loss: 6.7457 - acc: 0.4269 - val_loss: 7.2800 - val_acc: 0.3473
# Epoch 13/20
# 6660/6680 [============================>.] - ETA: 0s - loss: 6.5886 - acc: 0.4423Epoch 00013: val_loss improved from 7.27997 to 7.16275, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 243us/step - loss: 6.5786 - acc: 0.4427 - val_loss: 7.1627 - val_acc: 0.3653
# Epoch 14/20
# 6640/6680 [============================>.] - ETA: 0s - loss: 6.4387 - acc: 0.4598Epoch 00014: val_loss improved from 7.16275 to 7.05869, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 243us/step - loss: 6.4421 - acc: 0.4594 - val_loss: 7.0587 - val_acc: 0.3701
# Epoch 15/20
# 6640/6680 [============================>.] - ETA: 0s - loss: 6.3293 - acc: 0.4771Epoch 00015: val_loss improved from 7.05869 to 6.96154, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 242us/step - loss: 6.3318 - acc: 0.4765 - val_loss: 6.9615 - val_acc: 0.3892
# Epoch 16/20
# 6660/6680 [============================>.] - ETA: 0s - loss: 6.2247 - acc: 0.4905Epoch 00016: val_loss improved from 6.96154 to 6.88879, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 242us/step - loss: 6.2307 - acc: 0.4903 - val_loss: 6.8888 - val_acc: 0.3916
# Epoch 17/20
# 6480/6680 [============================>.] - ETA: 0s - loss: 6.1539 - acc: 0.5034Epoch 00017: val_loss improved from 6.88879 to 6.82802, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 239us/step - loss: 6.1467 - acc: 0.5043 - val_loss: 6.8280 - val_acc: 0.3904
# Epoch 18/20
# 6480/6680 [============================>.] - ETA: 0s - loss: 6.0996 - acc: 0.5148Epoch 00018: val_loss improved from 6.82802 to 6.77546, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 240us/step - loss: 6.0768 - acc: 0.5159 - val_loss: 6.7755 - val_acc: 0.4096
# Epoch 19/20
# 6500/6680 [============================>.] - ETA: 0s - loss: 5.9952 - acc: 0.5238Epoch 00019: val_loss improved from 6.77546 to 6.69820, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 238us/step - loss: 6.0151 - acc: 0.5222 - val_loss: 6.6982 - val_acc: 0.4084
# Epoch 20/20
# 6460/6680 [============================>.] - ETA: 0s - loss: 5.9397 - acc: 0.5331Epoch 00020: val_loss improved from 6.69820 to 6.65591, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 2s 240us/step - loss: 5.9471 - acc: 0.5329 - val_loss: 6.6559 - val_acc: 0.4096

# %% [markdown]
# ### Load the Model with the Best Validation Loss

# %%
VGG16_model.load_weights('saved_models/weights.best.VGG16.hdf5')

# %% [markdown]
# ### Test the Model
#
# Now, we can use the CNN to test how well it identifies breed within our test dataset of dog images.  We print the test accuracy below.

# %%
# get index of predicted dog breed for each image in test set
VGG16_predictions = [np.argmax(VGG16_model.predict(np.expand_dims(feature, axis=0))) for feature in test_VGG16]

# report test accuracy
test_accuracy = 100*np.sum(np.array(VGG16_predictions)==np.argmax(test_targets, axis=1))/len(VGG16_predictions)
print('Test accuracy: %.4f%%' % test_accuracy)
# Out:
# Test accuracy: 42.2249%

# %% [markdown]
# ### Predict Dog Breed with the Model

# %%
from extract_bottleneck_features import *

def VGG16_predict_breed(img_path):
    # extract bottleneck features
    bottleneck_feature = extract_VGG16(path_to_tensor(img_path))
    # obtain predicted vector
    predicted_vector = VGG16_model.predict(bottleneck_feature)
    # return dog breed that is predicted by the model
    return dog_names[np.argmax(predicted_vector)]

# %% [markdown]
# ---
# <a id='step5'></a>
# ## Step 5: Create a CNN to Classify Dog Breeds (using Transfer Learning)
#
# You will now use transfer learning to create a CNN that can identify dog breed from images.  Your CNN must attain at least 60% accuracy on the test set.
#
# In Step 4, we used transfer learning to create a CNN using VGG-16 bottleneck features.  In this section, you must use the bottleneck features from a different pre-trained model.  To make things easier for you, we have pre-computed the features for all of the networks that are currently available in Keras.  These are already in the workspace, at /data/bottleneck_features.  If you wish to download them on a different machine, they can be found at:
# - [VGG-19](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogVGG19Data.npz) bottleneck features
# - [ResNet-50](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogResnet50Data.npz) bottleneck features
# - [Inception](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogInceptionV3Data.npz) bottleneck features
# - [Xception](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogXceptionData.npz) bottleneck features
#
# The files are encoded as such:
#
#     Dog{network}Data.npz
#
# where `{network}`, in the above filename, can be one of `VGG19`, `Resnet50`, `InceptionV3`, or `Xception`.
#
# The above architectures are downloaded and stored for you in the `/data/bottleneck_features/` folder.
#
# This means the following will be in the `/data/bottleneck_features/` folder:
#
# `DogVGG19Data.npz`
# `DogResnet50Data.npz`
# `DogInceptionV3Data.npz`
# `DogXceptionData.npz`
#
#
#
# ### (IMPLEMENTATION) Obtain Bottleneck Features
#
# In the code block below, extract the bottleneck features corresponding to the train, test, and validation sets by running the following:
#
#     bottleneck_features = np.load('/data/bottleneck_features/Dog{network}Data.npz')
#     train_{network} = bottleneck_features['train']
#     valid_{network} = bottleneck_features['valid']
#     test_{network} = bottleneck_features['test']

# %%
### Obtain bottleneck features from another pre-trained CNN.
bottleneck_inception_features = np.load('/data/bottleneck_features/DogInceptionV3Data.npz')
train_inception = bottleneck_inception_features['train']
valid_inception = bottleneck_inception_features['valid']
test_inception = bottleneck_inception_features['test']

bottleneck_resnet_features = np.load('/data/bottleneck_features/DogResnet50Data.npz')
train_resnet = bottleneck_resnet_features['train']
valid_resnet = bottleneck_resnet_features['valid']
test_resnet = bottleneck_resnet_features['test']

bottleneck_vgg19_features = np.load('/data/bottleneck_features/DogVGG19Data.npz')
train_vgg19 = bottleneck_vgg19_features['train']
valid_vgg19 = bottleneck_vgg19_features['valid']
test_vgg19 = bottleneck_vgg19_features['test']

bottleneck_xception_features = np.load('/data/bottleneck_features/DogXceptionData.npz')
train_xception = bottleneck_xception_features['train']
valid_xception = bottleneck_xception_features['valid']
test_xception = bottleneck_xception_features['test']

# %% [markdown]
# ### (IMPLEMENTATION) Model Architecture
#
# Create a CNN to classify dog breed.  At the end of your code cell block, summarize the layers of your model by executing the line:
#
#         <your model's name>.summary()
#
# __Question 5:__ Outline the steps you took to get to your final CNN architecture and your reasoning at each step.  Describe why you think the architecture is suitable for the current problem.
#
# __Answer:__
# I played around with all different networks to practice and get a better feeling how to work with different networks.
#
# However, personally, I would go with the Xception architecture. Mostly, because the Xception architecture currently performs best in the Imagenet challenge. Its architecture is similar to the Inception architecture. Xception architecture has the same number of parameters s Inception V3, the performance gains are not due
# to increased capacity but rather to a more efficient use of model parameters.
#
# Source: <br/>
# https://arxiv.org/pdf/1610.02357.pdf

# %%
print(train_inception.shape)
print(train_resnet.shape)
print(train_vgg19.shape)
print(train_xception.shape)
# Out:
# (6680, 5, 5, 2048)
# (6680, 1, 1, 2048)
# (6680, 7, 7, 512)
# (6680, 7, 7, 2048)

# %%
from keras.models import Sequential
from keras.layers import Flatten, Dense, Dropout, GlobalAveragePooling2D

### Define your architecture.
model_inception = Sequential()
model_inception.add(GlobalAveragePooling2D(input_shape=(5,5,2048)))
model_inception.add(Dense(1024, activation='relu'))
model_inception.add(Dropout(0.5))
model_inception.add(Dense(133, activation='softmax'))
model_inception.summary()

model_resnet = Sequential()
model_resnet.add(GlobalAveragePooling2D(input_shape=(1,1,2048)))
model_resnet.add(Dense(133, activation='softmax'))
model_resnet.summary()

model_vgg19 = Sequential()
model_vgg19.add(GlobalAveragePooling2D(input_shape=(7, 7, 512)))
model_vgg19.add(Dense(512, activation='relu'))
model_vgg19.add(Dropout(0.5))
model_vgg19.add(Dense(133, activation='softmax'))
model_vgg19.summary()

model_xception = Sequential()
model_xception.add(GlobalAveragePooling2D(input_shape=(7,7,2048)))
model_xception.add(Dense(133, activation='softmax'))
model_xception.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# global_average_pooling2d_1 ( (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              2098176
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 133)               136325
# =================================================================
# Total params: 2,234,501
# Trainable params: 2,234,501
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# global_average_pooling2d_2 ( (None, 2048)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 133)               272517
# =================================================================
# Total params: 272,517
# Trainable params: 272,517
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# global_average_pooling2d_3 ( (None, 512)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 133)               68229
# =================================================================
# Total params: 330,885
# Trainable params: 330,885
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# global_average_pooling2d_4 ( (None, 2048)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 133)               272517
# =================================================================
# Total params: 272,517
# Trainable params: 272,517
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### (IMPLEMENTATION) Compile the Model

# %%
from keras import optimizers

### Compile the model.
model_inception.compile(loss='categorical_crossentropy', 
                        optimizer=optimizers.RMSprop(), 
                        metrics=['accuracy'])

model_resnet.compile(loss='categorical_crossentropy', 
                     optimizer=optimizers.RMSprop(lr=0.0001), 
                     metrics=['accuracy'])

model_vgg19.compile(loss='categorical_crossentropy', 
                    optimizer=optimizers.RMSprop(lr=0.0001), 
                    metrics=['accuracy'])

model_xception.compile(loss='categorical_crossentropy', 
                       optimizer=optimizers.RMSprop(lr=0.0001), 
                       metrics=['accuracy'])

# %% [markdown]
# ### (IMPLEMENTATION) Train the Model
#
# Train your model in the code cell below.  Use model checkpointing to save the model that attains the best validation loss.
#
# You are welcome to [augment the training data](https://blog.keras.io/building-powerful-image-classification-models-using-very-little-data.html), but this is not a requirement.

# %%
from keras.callbacks import ModelCheckpoint,  LearningRateScheduler

# %%
epochs = 30

checkpointer1 = ModelCheckpoint(filepath='saved_models/inception.weights.best.hdf5', 
                                 verbose=1, save_best_only=True)

def step_decay(epoch):
    if epoch > 20:
        return 0.000001
    return 0.00001

lrate = LearningRateScheduler(step_decay)

history_inception = model_inception.fit(train_inception, train_targets, 
                    validation_data=(valid_inception, valid_targets), 
                    epochs=epochs, batch_size=20, callbacks=[checkpointer1, lrate], verbose=1)
# Out:
# Train on 6680 samples, validate on 835 samples
# Epoch 1/30
# 6640/6680 [============================>.] - ETA: 0s - loss: 4.9067 - acc: 0.0340Epoch 00001: val_loss improved from inf to 4.11241, saving model to saved_models/inception.weights.best.hdf5
# 6680/6680 [==============================] - 3s 493us/step - loss: 4.9048 - acc: 0.0343 - val_loss: 4.1124 - val_acc: 0.2311
# Epoch 2/30
# 6600/6680 [============================>.] - ETA: 0s - loss: 3.9048 - acc: 0.2015Epoch 00002: val_loss improved from 4.11241 to 3.22758, saving model to saved_models/inception.weights.best.hdf5
# 6680/6680 [==============================] - 3s 466us/step - loss: 3.8995 - acc: 0.2033 - val_loss: 3.2276 - val_acc: 0.5497
# Epoch 3/30
# 6540/6680 [============================>.] - ETA: 0s - loss: 3.1122 - acc: 0.4003Epoch 00003: val_loss improved from 3.22758 to 2.44068, saving model to saved_models/inception.weights.best.hdf5
# 6680/6680 [==============================] - 3s 457us/step - loss: 3.1035 - acc: 0.4019 - val_loss: 2.4407 - val_acc: 0.6575
# Epoch 4/30
# 6600/6680 [============================>.] - ETA: 0s - loss: 2.4080 - acc: 0.5379Epoch 00004: val_loss improved from 2.44068 to 1.81975, saving model to saved_models/inception.weights.best.hdf5
# 6680/6680 [==============================] - 3s 455us/step - loss: 2.4049 - acc: 0.5382 - val_loss: 1.8198 - val_acc: 0.7054
# Epoch 5/30
# 6600/6680 [============================>.] - ETA: 0s - loss: 1.8923 - acc: 0.6153Epoch 00005: val_loss improved from 1.81975 to 1.39531, saving model to saved_models/inception.weights.best.hdf5
# 6680/6680 [==============================] - 3s 460us/step - loss: 1.8909 - acc: 0.6151 - val_loss: 1.3953 - val_acc: 0.7353
# Epoch 6/30
# 6660/6680 [============================>.] - ETA: 0s - loss: 1.5523 - acc: 0.6581Epoch 00006: val_loss improved from 1.39531 to 1.12540, saving model to saved_models/inception.weights.best.hdf5
# 6680/6680 [==============================] - 3s 460us/step - loss: 1.5509 - acc: 0.6582 - val_loss: 1.1254 - val_acc: 0.7665
# Epoch 7/30
# 6620/6680 [============================>.] - ETA: 0s - loss: 1.3022 - acc: 0.6962Epoch 00007: val_loss improved from 1.12540 to 0.94546, saving model to saved_models/inception.weights.best.hdf5
# 6680/6680 [==============================] - 3s 471us/step - loss: 1.3021 - acc: 0.6960 - val_loss: 0.9455 - val_acc: 0.7820
# Epoch 8/30
# 6580/6680 [============================>.] - ETA: 0s - loss: 1.1181 - acc: 0.7299Epoch 00008: val_loss improved from 0.94546 to 0.82847, saving model to saved_models/inception.weights.best.hdf5
# 6680/6680 [==============================] - 3s 463us/step - loss: 1.1157 - acc: 0.7301 - val_loss: 0.8285 - val_acc: 0.8012
# Epoch 9/30
# 6620/6680 [============================>.] - ETA: 0s - loss: 0.9982 - acc: 0.7396Epoch 00009: val_loss improved from 0.82847 to 0.74851, saving model to saved_models/inception.weights.best.hdf5
# 6680/6680 [==============================] - 3s 458us/step - loss: 0.9986 - acc: 0.7397 - val_loss: 0.7485 - val_acc: 0.8084
# Epoch 10/30
# 6620/6680 [============================>.] - ETA: 0s - loss: 0.9169 - acc: 0.7603Epoch 00010: val_loss improved from 0.74851 to 0.68872, saving model to saved_models/inception.weights.best.hdf5
# 6680/6680 [==============================] - 3s 460us/step - loss: 0.9142 - acc: 0.7609 - val_loss: 0.6887 - val_acc: 0.8168
# Epoch 11/30
# 6620/6680 [============================>.] - ETA: 0s - loss: 0.8490 - acc: 0.7666Epoch 00011: val_loss improved from 0.68872 to 0.64737, saving model to saved_models/inception.weights.best.hdf5
# 6680/6680 [==============================] - 3s 456us/step - loss: 0.8474 - acc: 0.7666 - val_loss: 0.6474 - val_acc: 0.8192
# Epoch 12/30
# 6580/6680 [============================>.] - ETA: 0s - loss: 0.7947 - acc: 0.7859Epoch 00012: val_loss improved from 0.64737 to 0.61761, saving model to saved_models/inception.weights.best.hdf5
# 6680/6680 [==============================] - 3s 453us/step - loss: 0.7938 - acc: 0.7858 - val_loss: 0.6176 - val_acc: 0.8228
# Epoch 13/30
# 6640/6680 [============================>.] - ETA: 0s - loss: 0.7252 - acc: 0.7962Epoch 00013: val_loss improved from 0.61761 to 0.58843, saving model to saved_models/inception.weights.best.hdf5
# 6680/6680 [==============================] - 3s 458us/step - loss: 0.7252 - acc: 0.7961 - val_loss: 0.5884 - val_acc: 0.8347
# Epoch 14/30
# 6640/6680 [============================>.] - ETA: 0s - loss: 0.6960 - acc: 0.8047Epoch 00014: val_loss improved from 0.58843 to 0.56979, saving model to saved_models/inception.weights.best.hdf5
# 6680/6680 [==============================] - 3s 468us/step - loss: 0.6951 - acc: 0.8048 - val_loss: 0.5698 - val_acc: 0.8395
# Epoch 15/30
# 6560/6680 [============================>.] - ETA: 0s - loss: 0.6611 - acc: 0.8084Epoch 00015: val_loss improved from 0.56979 to 0.55203, saving model to saved_models/inception.weights.best.hdf5
# 6680/6680 [==============================] - 3s 468us/step - loss: 0.6616 - acc: 0.8082 - val_loss: 0.5520 - val_acc: 0.8347
# Epoch 16/30
# 6560/6680 [============================>.] - ETA: 0s - loss: 0.6259 - acc: 0.8175Epoch 00016: val_loss improved from 0.55203 to 0.53917, saving model to saved_models/inception.weights.best.hdf5
# 6680/6680 [==============================] - 3s 466us/step - loss: 0.6261 - acc: 0.8171 - val_loss: 0.5392 - val_acc: 0.8371
# Epoch 17/30
# 6580/6680 [============================>.] - ETA: 0s - loss: 0.6072 - acc: 0.8210Epoch 00017: val_loss improved from 0.53917 to 0.52630, saving model to saved_models/inception.weights.best.hdf5
# 6680/6680 [==============================] - 3s 489us/step - loss: 0.6065 - acc: 0.8207 - val_loss: 0.5263 - val_acc: 0.8467
# Epoch 18/30
# 6580/6680 [============================>.] - ETA: 0s - loss: 0.5761 - acc: 0.8307Epoch 00018: val_loss improved from 0.52630 to 0.51998, saving model to saved_models/inception.weights.best.hdf5
# 6680/6680 [==============================] - 3s 483us/step - loss: 0.5747 - acc: 0.8311 - val_loss: 0.5200 - val_acc: 0.8383
# Epoch 19/30
# 6580/6680 [============================>.] - ETA: 0s - loss: 0.5624 - acc: 0.8310Epoch 00019: val_loss improved from 0.51998 to 0.51104, saving model to saved_models/inception.weights.best.hdf5
# 6680/6680 [==============================] - 3s 488us/step - loss: 0.5632 - acc: 0.8307 - val_loss: 0.5110 - val_acc: 0.8431
# Epoch 20/30
# 6560/6680 [============================>.] - ETA: 0s - loss: 0.5306 - acc: 0.8418Epoch 00020: val_loss improved from 0.51104 to 0.50237, saving model to saved_models/inception.weights.best.hdf5
# 6680/6680 [==============================] - 3s 479us/step - loss: 0.5308 - acc: 0.8418 - val_loss: 0.5024 - val_acc: 0.8443
# Epoch 21/30
# 6600/6680 [============================>.] - ETA: 0s - loss: 0.5109 - acc: 0.8485Epoch 00021: val_loss improved from 0.50237 to 0.50059, saving model to saved_models/inception.weights.best.hdf5
# 6680/6680 [==============================] - 3s 470us/step - loss: 0.5116 - acc: 0.8478 - val_loss: 0.5006 - val_acc: 0.8491
# Epoch 22/30
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.4939 - acc: 0.8503Epoch 00022: val_loss improved from 0.50059 to 0.49889, saving model to saved_models/inception.weights.best.hdf5
# 6680/6680 [==============================] - 3s 475us/step - loss: 0.4940 - acc: 0.8503 - val_loss: 0.4989 - val_acc: 0.8503
# Epoch 23/30
# 6560/6680 [============================>.] - ETA: 0s - loss: 0.4986 - acc: 0.8436Epoch 00023: val_loss improved from 0.49889 to 0.49723, saving model to saved_models/inception.weights.best.hdf5
# 6680/6680 [==============================] - 3s 472us/step - loss: 0.4998 - acc: 0.8439 - val_loss: 0.4972 - val_acc: 0.8539
# Epoch 24/30
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.5065 - acc: 0.8446Epoch 00024: val_loss improved from 0.49723 to 0.49652, saving model to saved_models/inception.weights.best.hdf5
# 6680/6680 [==============================] - 3s 496us/step - loss: 0.5068 - acc: 0.8445 - val_loss: 0.4965 - val_acc: 0.8503
# Epoch 25/30
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.5015 - acc: 0.8471Epoch 00025: val_loss improved from 0.49652 to 0.49562, saving model to saved_models/inception.weights.best.hdf5
# 6680/6680 [==============================] - 3s 471us/step - loss: 0.5016 - acc: 0.8470 - val_loss: 0.4956 - val_acc: 0.8491
# Epoch 26/30
# 6580/6680 [============================>.] - ETA: 0s - loss: 0.4961 - acc: 0.8483Epoch 00026: val_loss improved from 0.49562 to 0.49497, saving model to saved_models/inception.weights.best.hdf5
# 6680/6680 [==============================] - 3s 474us/step - loss: 0.4957 - acc: 0.8484 - val_loss: 0.4950 - val_acc: 0.8491
# Epoch 27/30
# 6560/6680 [============================>.] - ETA: 0s - loss: 0.4787 - acc: 0.8569Epoch 00027: val_loss improved from 0.49497 to 0.49444, saving model to saved_models/inception.weights.best.hdf5
# 6680/6680 [==============================] - 3s 474us/step - loss: 0.4809 - acc: 0.8564 - val_loss: 0.4944 - val_acc: 0.8527
# Epoch 28/30
# 6560/6680 [============================>.] - ETA: 0s - loss: 0.4893 - acc: 0.8523Epoch 00028: val_loss improved from 0.49444 to 0.49368, saving model to saved_models/inception.weights.best.hdf5
# 6680/6680 [==============================] - 3s 475us/step - loss: 0.4905 - acc: 0.8521 - val_loss: 0.4937 - val_acc: 0.8515
# Epoch 29/30
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.4806 - acc: 0.8548Epoch 00029: val_loss improved from 0.49368 to 0.49287, saving model to saved_models/inception.weights.best.hdf5
# 6680/6680 [==============================] - 3s 481us/step - loss: 0.4809 - acc: 0.8546 - val_loss: 0.4929 - val_acc: 0.8515
# Epoch 30/30
# 6600/6680 [============================>.] - ETA: 0s - loss: 0.4815 - acc: 0.8552Epoch 00030: val_loss improved from 0.49287 to 0.49225, saving model to saved_models/inception.weights.best.hdf5
# 6680/6680 [==============================] - 3s 479us/step - loss: 0.4830 - acc: 0.8549 - val_loss: 0.4923 - val_acc: 0.8527

# %%
epochs = 20

checkpointer2 = ModelCheckpoint(filepath='saved_models/resnet.weights.best.hdf5', 
                               verbose=1, save_best_only=True)

history_resnet = model_resnet.fit(train_resnet, train_targets, 
                    validation_data=(valid_resnet, valid_targets), 
                    epochs=epochs, batch_size=20, callbacks=[checkpointer2], verbose=1)
# Out:
# Train on 6680 samples, validate on 835 samples
# Epoch 1/20
# 6580/6680 [============================>.] - ETA: 0s - loss: 0.1562 - acc: 0.9579Epoch 00001: val_loss improved from inf to 0.54089, saving model to saved_models/resnet.weights.best.hdf5
# 6680/6680 [==============================] - 2s 245us/step - loss: 0.1564 - acc: 0.9578 - val_loss: 0.5409 - val_acc: 0.8204
# Epoch 2/20
# 6580/6680 [============================>.] - ETA: 0s - loss: 0.1501 - acc: 0.9614Epoch 00002: val_loss improved from 0.54089 to 0.53375, saving model to saved_models/resnet.weights.best.hdf5
# 6680/6680 [==============================] - 1s 214us/step - loss: 0.1495 - acc: 0.9614 - val_loss: 0.5338 - val_acc: 0.8287
# Epoch 3/20
# 6520/6680 [============================>.] - ETA: 0s - loss: 0.1441 - acc: 0.9606Epoch 00003: val_loss did not improve
# 6680/6680 [==============================] - 1s 214us/step - loss: 0.1420 - acc: 0.9615 - val_loss: 0.5372 - val_acc: 0.8299
# Epoch 4/20
# 6460/6680 [============================>.] - ETA: 0s - loss: 0.1353 - acc: 0.9635Epoch 00004: val_loss improved from 0.53375 to 0.53334, saving model to saved_models/resnet.weights.best.hdf5
# 6680/6680 [==============================] - 1s 218us/step - loss: 0.1365 - acc: 0.9629 - val_loss: 0.5333 - val_acc: 0.8180
# Epoch 5/20
# 6560/6680 [============================>.] - ETA: 0s - loss: 0.1321 - acc: 0.9623Epoch 00005: val_loss improved from 0.53334 to 0.53067, saving model to saved_models/resnet.weights.best.hdf5
# 6680/6680 [==============================] - 1s 216us/step - loss: 0.1316 - acc: 0.9624 - val_loss: 0.5307 - val_acc: 0.8192
# Epoch 6/20
# 6540/6680 [============================>.] - ETA: 0s - loss: 0.1260 - acc: 0.9659Epoch 00006: val_loss did not improve
# 6680/6680 [==============================] - 1s 213us/step - loss: 0.1258 - acc: 0.9660 - val_loss: 0.5353 - val_acc: 0.8263
# Epoch 7/20
# 6480/6680 [============================>.] - ETA: 0s - loss: 0.1218 - acc: 0.9660Epoch 00007: val_loss improved from 0.53067 to 0.52437, saving model to saved_models/resnet.weights.best.hdf5
# 6680/6680 [==============================] - 1s 217us/step - loss: 0.1221 - acc: 0.9654 - val_loss: 0.5244 - val_acc: 0.8287
# Epoch 8/20
# 6480/6680 [============================>.] - ETA: 0s - loss: 0.1179 - acc: 0.9674Epoch 00008: val_loss did not improve
# 6680/6680 [==============================] - 1s 214us/step - loss: 0.1166 - acc: 0.9680 - val_loss: 0.5423 - val_acc: 0.8275
# Epoch 9/20
# 6440/6680 [===========================>..] - ETA: 0s - loss: 0.1107 - acc: 0.9677Epoch 00009: val_loss did not improve
# 6680/6680 [==============================] - 1s 215us/step - loss: 0.1131 - acc: 0.9674 - val_loss: 0.5297 - val_acc: 0.8204
# Epoch 10/20
# 6520/6680 [============================>.] - ETA: 0s - loss: 0.1108 - acc: 0.9687Epoch 00010: val_loss did not improve
# 6680/6680 [==============================] - 1s 213us/step - loss: 0.1099 - acc: 0.9689 - val_loss: 0.5391 - val_acc: 0.8263
# Epoch 11/20
# 6540/6680 [============================>.] - ETA: 0s - loss: 0.1083 - acc: 0.9691Epoch 00011: val_loss did not improve
# 6680/6680 [==============================] - 1s 213us/step - loss: 0.1078 - acc: 0.9692 - val_loss: 0.5410 - val_acc: 0.8251
# Epoch 12/20
# 6600/6680 [============================>.] - ETA: 0s - loss: 0.1029 - acc: 0.9702Epoch 00012: val_loss did not improve
# 6680/6680 [==============================] - 1s 210us/step - loss: 0.1025 - acc: 0.9704 - val_loss: 0.5383 - val_acc: 0.8299
# Epoch 13/20
# 6540/6680 [============================>.] - ETA: 0s - loss: 0.1008 - acc: 0.9722Epoch 00013: val_loss did not improve
# 6680/6680 [==============================] - 1s 210us/step - loss: 0.1002 - acc: 0.9723 - val_loss: 0.5379 - val_acc: 0.8251
# Epoch 14/20
# 6640/6680 [============================>.] - ETA: 0s - loss: 0.0968 - acc: 0.9709Epoch 00014: val_loss did not improve
# 6680/6680 [==============================] - 1s 208us/step - loss: 0.0966 - acc: 0.9711 - val_loss: 0.5466 - val_acc: 0.8323
# Epoch 15/20
# 6560/6680 [============================>.] - ETA: 0s - loss: 0.0939 - acc: 0.9724Epoch 00015: val_loss did not improve
# 6680/6680 [==============================] - 1s 211us/step - loss: 0.0941 - acc: 0.9726 - val_loss: 0.5412 - val_acc: 0.8240
# Epoch 16/20
# 6520/6680 [============================>.] - ETA: 0s - loss: 0.0923 - acc: 0.9735Epoch 00016: val_loss did not improve
# 6680/6680 [==============================] - 1s 213us/step - loss: 0.0920 - acc: 0.9737 - val_loss: 0.5396 - val_acc: 0.8287
# Epoch 17/20
# 6520/6680 [============================>.] - ETA: 0s - loss: 0.0896 - acc: 0.9738Epoch 00017: val_loss did not improve
# 6680/6680 [==============================] - 1s 211us/step - loss: 0.0896 - acc: 0.9735 - val_loss: 0.5409 - val_acc: 0.8335
# Epoch 18/20
# 6540/6680 [============================>.] - ETA: 0s - loss: 0.0872 - acc: 0.9739Epoch 00018: val_loss did not improve
# 6680/6680 [==============================] - 1s 213us/step - loss: 0.0870 - acc: 0.9738 - val_loss: 0.5497 - val_acc: 0.8371
# Epoch 19/20
# 6540/6680 [============================>.] - ETA: 0s - loss: 0.0856 - acc: 0.9748Epoch 00019: val_loss did not improve
# 6680/6680 [==============================] - 1s 213us/step - loss: 0.0856 - acc: 0.9746 - val_loss: 0.5409 - val_acc: 0.8371
# Epoch 20/20
# 6600/6680 [============================>.] - ETA: 0s - loss: 0.0821 - acc: 0.9756Epoch 00020: val_loss did not improve
# 6680/6680 [==============================] - 1s 210us/step - loss: 0.0821 - acc: 0.9756 - val_loss: 0.5460 - val_acc: 0.8359

# %%
epochs = 60

checkpointer3 = ModelCheckpoint(filepath='saved_models/vgg19.weights.best.hdf5', 
                               verbose=1, save_best_only=True)

history_vgg19 = model_vgg19.fit(train_vgg19, train_targets, 
                    validation_data=(valid_vgg19, valid_targets), 
                    epochs=epochs, batch_size=20, callbacks=[checkpointer3], verbose=1)
# Out:
# Train on 6680 samples, validate on 835 samples
# Epoch 1/60
# 6600/6680 [============================>.] - ETA: 0s - loss: 12.0319 - acc: 0.0277Epoch 00001: val_loss improved from inf to 5.12269, saving model to saved_models/vgg19.weights.best.hdf5
# 6680/6680 [==============================] - 2s 357us/step - loss: 11.9760 - acc: 0.0280 - val_loss: 5.1227 - val_acc: 0.1305
# Epoch 2/60
# 6560/6680 [============================>.] - ETA: 0s - loss: 5.2785 - acc: 0.1044Epoch 00002: val_loss improved from 5.12269 to 3.22121, saving model to saved_models/vgg19.weights.best.hdf5
# 6680/6680 [==============================] - 2s 299us/step - loss: 5.2594 - acc: 0.1051 - val_loss: 3.2212 - val_acc: 0.2886
# Epoch 3/60
# 6480/6680 [============================>.] - ETA: 0s - loss: 3.5506 - acc: 0.2207Epoch 00003: val_loss improved from 3.22121 to 2.42506, saving model to saved_models/vgg19.weights.best.hdf5
# 6680/6680 [==============================] - 2s 294us/step - loss: 3.5408 - acc: 0.2220 - val_loss: 2.4251 - val_acc: 0.4048
# Epoch 4/60
# 6520/6680 [============================>.] - ETA: 0s - loss: 2.8059 - acc: 0.3425Epoch 00004: val_loss improved from 2.42506 to 1.90244, saving model to saved_models/vgg19.weights.best.hdf5
# 6680/6680 [==============================] - 2s 294us/step - loss: 2.8007 - acc: 0.3440 - val_loss: 1.9024 - val_acc: 0.5150
# Epoch 5/60
# 6660/6680 [============================>.] - ETA: 0s - loss: 2.2820 - acc: 0.4437Epoch 00005: val_loss improved from 1.90244 to 1.58029, saving model to saved_models/vgg19.weights.best.hdf5
# 6680/6680 [==============================] - 2s 298us/step - loss: 2.2822 - acc: 0.4436 - val_loss: 1.5803 - val_acc: 0.5545
# Epoch 6/60
# 6560/6680 [============================>.] - ETA: 0s - loss: 1.9288 - acc: 0.5046Epoch 00006: val_loss improved from 1.58029 to 1.40178, saving model to saved_models/vgg19.weights.best.hdf5
# 6680/6680 [==============================] - 2s 290us/step - loss: 1.9296 - acc: 0.5045 - val_loss: 1.4018 - val_acc: 0.6024
# Epoch 7/60
# 6620/6680 [============================>.] - ETA: 0s - loss: 1.6643 - acc: 0.5579Epoch 00007: val_loss improved from 1.40178 to 1.24236, saving model to saved_models/vgg19.weights.best.hdf5
# 6680/6680 [==============================] - 2s 289us/step - loss: 1.6629 - acc: 0.5581 - val_loss: 1.2424 - val_acc: 0.6455
# Epoch 8/60
# 6600/6680 [============================>.] - ETA: 0s - loss: 1.4793 - acc: 0.6020Epoch 00008: val_loss improved from 1.24236 to 1.13882, saving model to saved_models/vgg19.weights.best.hdf5
# 6680/6680 [==============================] - 2s 290us/step - loss: 1.4785 - acc: 0.6019 - val_loss: 1.1388 - val_acc: 0.6611
# Epoch 9/60
# 6540/6680 [============================>.] - ETA: 0s - loss: 1.3154 - acc: 0.6465Epoch 00009: val_loss improved from 1.13882 to 1.07954, saving model to saved_models/vgg19.weights.best.hdf5
# 6680/6680 [==============================] - 2s 294us/step - loss: 1.3128 - acc: 0.6478 - val_loss: 1.0795 - val_acc: 0.6766
# Epoch 10/60
# 6560/6680 [============================>.] - ETA: 0s - loss: 1.1785 - acc: 0.6814Epoch 00010: val_loss improved from 1.07954 to 1.03365, saving model to saved_models/vgg19.weights.best.hdf5
# 6680/6680 [==============================] - 2s 292us/step - loss: 1.1760 - acc: 0.6822 - val_loss: 1.0337 - val_acc: 0.6970
# Epoch 11/60
# 6560/6680 [============================>.] - ETA: 0s - loss: 1.0783 - acc: 0.6983Epoch 00011: val_loss improved from 1.03365 to 0.98226, saving model to saved_models/vgg19.weights.best.hdf5
# 6680/6680 [==============================] - 2s 292us/step - loss: 1.0784 - acc: 0.6982 - val_loss: 0.9823 - val_acc: 0.6910
# Epoch 12/60
# 6500/6680 [============================>.] - ETA: 0s - loss: 0.9993 - acc: 0.7112Epoch 00012: val_loss improved from 0.98226 to 0.95870, saving model to saved_models/vgg19.weights.best.hdf5
# 6680/6680 [==============================] - 2s 294us/step - loss: 0.9975 - acc: 0.7120 - val_loss: 0.9587 - val_acc: 0.7054
# Epoch 13/60
# 6560/6680 [============================>.] - ETA: 0s - loss: 0.9122 - acc: 0.7340Epoch 00013: val_loss improved from 0.95870 to 0.90697, saving model to saved_models/vgg19.weights.best.hdf5
# 6680/6680 [==============================] - 2s 293us/step - loss: 0.9070 - acc: 0.7350 - val_loss: 0.9070 - val_acc: 0.7257
# Epoch 14/60
# 6600/6680 [============================>.] - ETA: 0s - loss: 0.8442 - acc: 0.7536Epoch 00014: val_loss improved from 0.90697 to 0.88939, saving model to saved_models/vgg19.weights.best.hdf5
# 6680/6680 [==============================] - 2s 291us/step - loss: 0.8426 - acc: 0.7533 - val_loss: 0.8894 - val_acc: 0.7257
# Epoch 15/60
# 6640/6680 [============================>.] - ETA: 0s - loss: 0.7801 - acc: 0.7741Epoch 00015: val_loss did not improve
# 6680/6680 [==============================] - 2s 293us/step - loss: 0.7797 - acc: 0.7743 - val_loss: 0.8929 - val_acc: 0.7377
# Epoch 16/60
# 6540/6680 [============================>.] - ETA: 0s - loss: 0.7113 - acc: 0.7916Epoch 00016: val_loss improved from 0.88939 to 0.86888, saving model to saved_models/vgg19.weights.best.hdf5
# 6680/6680 [==============================] - 2s 302us/step - loss: 0.7088 - acc: 0.7915 - val_loss: 0.8689 - val_acc: 0.7341
# Epoch 17/60
# 6600/6680 [============================>.] - ETA: 0s - loss: 0.6775 - acc: 0.7967Epoch 00017: val_loss improved from 0.86888 to 0.85955, saving model to saved_models/vgg19.weights.best.hdf5
# 6680/6680 [==============================] - 2s 298us/step - loss: 0.6784 - acc: 0.7967 - val_loss: 0.8595 - val_acc: 0.7437
# Epoch 18/60
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.6301 - acc: 0.8141Epoch 00018: val_loss improved from 0.85955 to 0.85754, saving model to saved_models/vgg19.weights.best.hdf5
# 6680/6680 [==============================] - 2s 305us/step - loss: 0.6334 - acc: 0.8138 - val_loss: 0.8575 - val_acc: 0.7533
# Epoch 19/60
# 6540/6680 [============================>.] - ETA: 0s - loss: 0.5932 - acc: 0.8234Epoch 00019: val_loss improved from 0.85754 to 0.81514, saving model to saved_models/vgg19.weights.best.hdf5
# 6680/6680 [==============================] - 2s 309us/step - loss: 0.5911 - acc: 0.8241 - val_loss: 0.8151 - val_acc: 0.7653
# Epoch 20/60
# 6640/6680 [============================>.] - ETA: 0s - loss: 0.5857 - acc: 0.8264Epoch 00020: val_loss did not improve
# 6680/6680 [==============================] - 2s 309us/step - loss: 0.5865 - acc: 0.8266 - val_loss: 0.8216 - val_acc: 0.7629
# Epoch 21/60
# 6520/6680 [============================>.] - ETA: 0s - loss: 0.5284 - acc: 0.8417Epoch 00021: val_loss improved from 0.81514 to 0.80708, saving model to saved_models/vgg19.weights.best.hdf5
# 6680/6680 [==============================] - 2s 300us/step - loss: 0.5280 - acc: 0.8421 - val_loss: 0.8071 - val_acc: 0.7677
# Epoch 22/60
# 6580/6680 [============================>.] - ETA: 0s - loss: 0.4921 - acc: 0.8483Epoch 00022: val_loss did not improve
# 6680/6680 [==============================] - 2s 298us/step - loss: 0.4911 - acc: 0.8484 - val_loss: 0.8129 - val_acc: 0.7665
# Epoch 23/60
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.4824 - acc: 0.8568Epoch 00023: val_loss improved from 0.80708 to 0.78307, saving model to saved_models/vgg19.weights.best.hdf5
# 6680/6680 [==============================] - 2s 300us/step - loss: 0.4827 - acc: 0.8566 - val_loss: 0.7831 - val_acc: 0.7737
# Epoch 24/60
# 6480/6680 [============================>.] - ETA: 0s - loss: 0.4602 - acc: 0.8602Epoch 00024: val_loss improved from 0.78307 to 0.78206, saving model to saved_models/vgg19.weights.best.hdf5
# 6680/6680 [==============================] - 2s 294us/step - loss: 0.4586 - acc: 0.8609 - val_loss: 0.7821 - val_acc: 0.7868
# Epoch 25/60
# 6500/6680 [============================>.] - ETA: 0s - loss: 0.4375 - acc: 0.8655Epoch 00025: val_loss did not improve
# 6680/6680 [==============================] - 2s 291us/step - loss: 0.4394 - acc: 0.8651 - val_loss: 0.8143 - val_acc: 0.7725
# Epoch 26/60
# 6480/6680 [============================>.] - ETA: 0s - loss: 0.4074 - acc: 0.8781Epoch 00026: val_loss did not improve
# 6680/6680 [==============================] - 2s 293us/step - loss: 0.4063 - acc: 0.8781 - val_loss: 0.7946 - val_acc: 0.7772
# Epoch 27/60
# 6520/6680 [============================>.] - ETA: 0s - loss: 0.3885 - acc: 0.8770Epoch 00027: val_loss improved from 0.78206 to 0.78160, saving model to saved_models/vgg19.weights.best.hdf5
# 6680/6680 [==============================] - 2s 298us/step - loss: 0.3865 - acc: 0.8778 - val_loss: 0.7816 - val_acc: 0.7832
# Epoch 28/60
# 6500/6680 [============================>.] - ETA: 0s - loss: 0.3579 - acc: 0.8895Epoch 00028: val_loss did not improve
# 6680/6680 [==============================] - 2s 294us/step - loss: 0.3577 - acc: 0.8894 - val_loss: 0.7859 - val_acc: 0.7808
# Epoch 29/60
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.3524 - acc: 0.8877Epoch 00029: val_loss did not improve
# 6680/6680 [==============================] - 2s 293us/step - loss: 0.3529 - acc: 0.8873 - val_loss: 0.7941 - val_acc: 0.7808
# Epoch 30/60
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.3327 - acc: 0.8935Epoch 00030: val_loss improved from 0.78160 to 0.78015, saving model to saved_models/vgg19.weights.best.hdf5
# 6680/6680 [==============================] - 2s 296us/step - loss: 0.3320 - acc: 0.8939 - val_loss: 0.7801 - val_acc: 0.7844
# Epoch 31/60
# 6580/6680 [============================>.] - ETA: 0s - loss: 0.3408 - acc: 0.8941Epoch 00031: val_loss did not improve
# 6680/6680 [==============================] - 2s 283us/step - loss: 0.3408 - acc: 0.8943 - val_loss: 0.7982 - val_acc: 0.7832
# Epoch 32/60
# 6600/6680 [============================>.] - ETA: 0s - loss: 0.3099 - acc: 0.9033Epoch 00032: val_loss improved from 0.78015 to 0.77882, saving model to saved_models/vgg19.weights.best.hdf5
# 6680/6680 [==============================] - 2s 285us/step - loss: 0.3093 - acc: 0.9036 - val_loss: 0.7788 - val_acc: 0.7796
# Epoch 33/60
# 6620/6680 [============================>.] - ETA: 0s - loss: 0.2901 - acc: 0.9048Epoch 00033: val_loss did not improve
# 6680/6680 [==============================] - 2s 293us/step - loss: 0.2921 - acc: 0.9043 - val_loss: 0.7984 - val_acc: 0.7713
# Epoch 34/60
# 6520/6680 [============================>.] - ETA: 0s - loss: 0.2889 - acc: 0.9115Epoch 00034: val_loss improved from 0.77882 to 0.77837, saving model to saved_models/vgg19.weights.best.hdf5
# 6680/6680 [==============================] - 2s 295us/step - loss: 0.2881 - acc: 0.9114 - val_loss: 0.7784 - val_acc: 0.7749
# Epoch 35/60
# 6560/6680 [============================>.] - ETA: 0s - loss: 0.2888 - acc: 0.9087Epoch 00035: val_loss did not improve
# 6680/6680 [==============================] - 2s 290us/step - loss: 0.2875 - acc: 0.9090 - val_loss: 0.8084 - val_acc: 0.7772
# Epoch 36/60
# 6580/6680 [============================>.] - ETA: 0s - loss: 0.2654 - acc: 0.9137Epoch 00036: val_loss did not improve
# 6680/6680 [==============================] - 2s 282us/step - loss: 0.2653 - acc: 0.9135 - val_loss: 0.7901 - val_acc: 0.7880
# Epoch 37/60
# 6620/6680 [============================>.] - ETA: 0s - loss: 0.2576 - acc: 0.9189Epoch 00037: val_loss did not improve
# 6680/6680 [==============================] - 2s 282us/step - loss: 0.2586 - acc: 0.9192 - val_loss: 0.7917 - val_acc: 0.7808
# Epoch 38/60
# 6620/6680 [============================>.] - ETA: 0s - loss: 0.2353 - acc: 0.9264Epoch 00038: val_loss did not improve
# 6680/6680 [==============================] - 2s 277us/step - loss: 0.2351 - acc: 0.9265 - val_loss: 0.8118 - val_acc: 0.7784
# Epoch 39/60
# 6620/6680 [============================>.] - ETA: 0s - loss: 0.2315 - acc: 0.9267Epoch 00039: val_loss did not improve
# 6680/6680 [==============================] - 2s 280us/step - loss: 0.2307 - acc: 0.9269 - val_loss: 0.8084 - val_acc: 0.7928
# Epoch 40/60
# 6560/6680 [============================>.] - ETA: 0s - loss: 0.2306 - acc: 0.9277Epoch 00040: val_loss did not improve
# 6680/6680 [==============================] - 2s 281us/step - loss: 0.2330 - acc: 0.9277 - val_loss: 0.7991 - val_acc: 0.7880
# Epoch 41/60
# 6600/6680 [============================>.] - ETA: 0s - loss: 0.2043 - acc: 0.9324Epoch 00041: val_loss did not improve
# 6680/6680 [==============================] - 2s 284us/step - loss: 0.2030 - acc: 0.9329 - val_loss: 0.8154 - val_acc: 0.7964
# Epoch 42/60
# 6540/6680 [============================>.] - ETA: 0s - loss: 0.2092 - acc: 0.9343Epoch 00042: val_loss did not improve
# 6680/6680 [==============================] - 2s 290us/step - loss: 0.2081 - acc: 0.9346 - val_loss: 0.7955 - val_acc: 0.7904
# Epoch 43/60
# 6580/6680 [============================>.] - ETA: 0s - loss: 0.2060 - acc: 0.9348Epoch 00043: val_loss did not improve
# 6680/6680 [==============================] - 2s 290us/step - loss: 0.2050 - acc: 0.9352 - val_loss: 0.8133 - val_acc: 0.7880
# Epoch 44/60
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.1956 - acc: 0.9338Epoch 00044: val_loss did not improve
# 6680/6680 [==============================] - 2s 293us/step - loss: 0.1953 - acc: 0.9338 - val_loss: 0.8285 - val_acc: 0.7856
# Epoch 45/60
# 6560/6680 [============================>.] - ETA: 0s - loss: 0.1972 - acc: 0.9352Epoch 00045: val_loss did not improve
# 6680/6680 [==============================] - 2s 290us/step - loss: 0.1960 - acc: 0.9355 - val_loss: 0.8094 - val_acc: 0.7856
# Epoch 46/60
# 6580/6680 [============================>.] - ETA: 0s - loss: 0.1909 - acc: 0.9424Epoch 00046: val_loss did not improve
# 6680/6680 [==============================] - 2s 291us/step - loss: 0.1896 - acc: 0.9425 - val_loss: 0.8153 - val_acc: 0.7904
# Epoch 47/60
# 6480/6680 [============================>.] - ETA: 0s - loss: 0.1636 - acc: 0.9463Epoch 00047: val_loss did not improve
# 6680/6680 [==============================] - 2s 293us/step - loss: 0.1631 - acc: 0.9464 - val_loss: 0.8091 - val_acc: 0.7880
# Epoch 48/60
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.1639 - acc: 0.9446Epoch 00048: val_loss did not improve
# 6680/6680 [==============================] - 2s 293us/step - loss: 0.1644 - acc: 0.9443 - val_loss: 0.8219 - val_acc: 0.7892
# Epoch 49/60
# 6600/6680 [============================>.] - ETA: 0s - loss: 0.1625 - acc: 0.9492Epoch 00049: val_loss did not improve
# 6680/6680 [==============================] - 2s 312us/step - loss: 0.1638 - acc: 0.9484 - val_loss: 0.8300 - val_acc: 0.7808
# Epoch 50/60
# 6520/6680 [============================>.] - ETA: 0s - loss: 0.1587 - acc: 0.9479Epoch 00050: val_loss did not improve
# 6680/6680 [==============================] - 2s 314us/step - loss: 0.1600 - acc: 0.9472 - val_loss: 0.8226 - val_acc: 0.7916
# Epoch 51/60
# 6500/6680 [============================>.] - ETA: 0s - loss: 0.1643 - acc: 0.9458Epoch 00051: val_loss did not improve
# 6680/6680 [==============================] - 2s 313us/step - loss: 0.1626 - acc: 0.9464 - val_loss: 0.8148 - val_acc: 0.7892
# Epoch 52/60
# 6600/6680 [============================>.] - ETA: 0s - loss: 0.1617 - acc: 0.9489Epoch 00052: val_loss did not improve
# 6680/6680 [==============================] - 2s 314us/step - loss: 0.1613 - acc: 0.9493 - val_loss: 0.8407 - val_acc: 0.8048
# Epoch 53/60
# 6540/6680 [============================>.] - ETA: 0s - loss: 0.1517 - acc: 0.9520Epoch 00053: val_loss did not improve
# 6680/6680 [==============================] - 2s 297us/step - loss: 0.1534 - acc: 0.9513 - val_loss: 0.8642 - val_acc: 0.7868
# Epoch 54/60
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.1417 - acc: 0.9533Epoch 00054: val_loss did not improve
# 6680/6680 [==============================] - 2s 278us/step - loss: 0.1413 - acc: 0.9534 - val_loss: 0.8390 - val_acc: 0.7868
# Epoch 55/60
# 6600/6680 [============================>.] - ETA: 0s - loss: 0.1323 - acc: 0.9565Epoch 00055: val_loss did not improve
# 6680/6680 [==============================] - 2s 281us/step - loss: 0.1337 - acc: 0.9563 - val_loss: 0.8465 - val_acc: 0.7892
# Epoch 56/60
# 6580/6680 [============================>.] - ETA: 0s - loss: 0.1365 - acc: 0.9555Epoch 00056: val_loss did not improve
# 6680/6680 [==============================] - 2s 283us/step - loss: 0.1374 - acc: 0.9554 - val_loss: 0.8410 - val_acc: 0.7844
# Epoch 57/60
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.1352 - acc: 0.9569Epoch 00057: val_loss did not improve
# 6680/6680 [==============================] - 2s 290us/step - loss: 0.1349 - acc: 0.9570 - val_loss: 0.8590 - val_acc: 0.7976
# Epoch 58/60
# 6580/6680 [============================>.] - ETA: 0s - loss: 0.1326 - acc: 0.9556Epoch 00058: val_loss did not improve
# 6680/6680 [==============================] - 2s 285us/step - loss: 0.1329 - acc: 0.9557 - val_loss: 0.8611 - val_acc: 0.8000
# Epoch 59/60
# 6500/6680 [============================>.] - ETA: 0s - loss: 0.1235 - acc: 0.9591Epoch 00059: val_loss did not improve
# 6680/6680 [==============================] - 2s 289us/step - loss: 0.1237 - acc: 0.9591 - val_loss: 0.8741 - val_acc: 0.7868
# Epoch 60/60
# 6540/6680 [============================>.] - ETA: 0s - loss: 0.1264 - acc: 0.9602Epoch 00060: val_loss did not improve
# 6680/6680 [==============================] - 2s 285us/step - loss: 0.1261 - acc: 0.9605 - val_loss: 0.8454 - val_acc: 0.7964

# %%
epochs = 20

checkpointer4 = ModelCheckpoint(filepath='saved_models/xception1.weights.best.hdf5', 
                               verbose=1, save_best_only=True)

history_xception = model_xception.fit(train_xception, train_targets, 
                    validation_data=(valid_xception, valid_targets), 
                    epochs=epochs, batch_size=20, callbacks=[checkpointer4], verbose=1)
# Out:
# Train on 6680 samples, validate on 835 samples
# Epoch 1/20
# 6640/6680 [============================>.] - ETA: 0s - loss: 0.4759 - acc: 0.8708Epoch 00001: val_loss improved from inf to 0.53189, saving model to saved_models/xception1.weights.best.hdf5
# 6680/6680 [==============================] - 3s 436us/step - loss: 0.4766 - acc: 0.8701 - val_loss: 0.5319 - val_acc: 0.8431
# Epoch 2/20
# 6600/6680 [============================>.] - ETA: 0s - loss: 0.4292 - acc: 0.8794Epoch 00002: val_loss improved from 0.53189 to 0.50875, saving model to saved_models/xception1.weights.best.hdf5
# 6680/6680 [==============================] - 3s 409us/step - loss: 0.4297 - acc: 0.8789 - val_loss: 0.5087 - val_acc: 0.8491
# Epoch 3/20
# 6520/6680 [============================>.] - ETA: 0s - loss: 0.4007 - acc: 0.8821Epoch 00003: val_loss improved from 0.50875 to 0.48569, saving model to saved_models/xception1.weights.best.hdf5
# 6680/6680 [==============================] - 3s 397us/step - loss: 0.3982 - acc: 0.8826 - val_loss: 0.4857 - val_acc: 0.8539
# Epoch 4/20
# 6600/6680 [============================>.] - ETA: 0s - loss: 0.3767 - acc: 0.8880Epoch 00004: val_loss improved from 0.48569 to 0.47303, saving model to saved_models/xception1.weights.best.hdf5
# 6680/6680 [==============================] - 3s 395us/step - loss: 0.3770 - acc: 0.8879 - val_loss: 0.4730 - val_acc: 0.8563
# Epoch 5/20
# 6600/6680 [============================>.] - ETA: 0s - loss: 0.3592 - acc: 0.8938Epoch 00005: val_loss improved from 0.47303 to 0.46689, saving model to saved_models/xception1.weights.best.hdf5
# 6680/6680 [==============================] - 3s 390us/step - loss: 0.3583 - acc: 0.8942 - val_loss: 0.4669 - val_acc: 0.8539
# Epoch 6/20
# 6620/6680 [============================>.] - ETA: 0s - loss: 0.3442 - acc: 0.8973Epoch 00006: val_loss improved from 0.46689 to 0.45804, saving model to saved_models/xception1.weights.best.hdf5
# 6680/6680 [==============================] - 3s 399us/step - loss: 0.3448 - acc: 0.8970 - val_loss: 0.4580 - val_acc: 0.8551
# Epoch 7/20
# 6620/6680 [============================>.] - ETA: 0s - loss: 0.3324 - acc: 0.9000Epoch 00007: val_loss improved from 0.45804 to 0.45567, saving model to saved_models/xception1.weights.best.hdf5
# 6680/6680 [==============================] - 3s 391us/step - loss: 0.3324 - acc: 0.8994 - val_loss: 0.4557 - val_acc: 0.8503
# Epoch 8/20
# 6560/6680 [============================>.] - ETA: 0s - loss: 0.3237 - acc: 0.9015Epoch 00008: val_loss improved from 0.45567 to 0.45222, saving model to saved_models/xception1.weights.best.hdf5
# 6680/6680 [==============================] - 3s 402us/step - loss: 0.3226 - acc: 0.9016 - val_loss: 0.4522 - val_acc: 0.8503
# Epoch 9/20
# 6580/6680 [============================>.] - ETA: 0s - loss: 0.3136 - acc: 0.9058Epoch 00009: val_loss improved from 0.45222 to 0.44758, saving model to saved_models/xception1.weights.best.hdf5
# 6680/6680 [==============================] - 3s 403us/step - loss: 0.3133 - acc: 0.9057 - val_loss: 0.4476 - val_acc: 0.8527
# Epoch 10/20
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.3039 - acc: 0.9081Epoch 00010: val_loss improved from 0.44758 to 0.44704, saving model to saved_models/xception1.weights.best.hdf5
# 6680/6680 [==============================] - 3s 398us/step - loss: 0.3046 - acc: 0.9075 - val_loss: 0.4470 - val_acc: 0.8527
# Epoch 11/20
# 6540/6680 [============================>.] - ETA: 0s - loss: 0.2947 - acc: 0.9089Epoch 00011: val_loss improved from 0.44704 to 0.44692, saving model to saved_models/xception1.weights.best.hdf5
# 6680/6680 [==============================] - 3s 400us/step - loss: 0.2980 - acc: 0.9067 - val_loss: 0.4469 - val_acc: 0.8503
# Epoch 12/20
# 6640/6680 [============================>.] - ETA: 0s - loss: 0.2896 - acc: 0.9101Epoch 00012: val_loss improved from 0.44692 to 0.44136, saving model to saved_models/xception1.weights.best.hdf5
# 6680/6680 [==============================] - 3s 401us/step - loss: 0.2909 - acc: 0.9096 - val_loss: 0.4414 - val_acc: 0.8491
# Epoch 13/20
# 6580/6680 [============================>.] - ETA: 0s - loss: 0.2857 - acc: 0.9134Epoch 00013: val_loss improved from 0.44136 to 0.44117, saving model to saved_models/xception1.weights.best.hdf5
# 6680/6680 [==============================] - 3s 398us/step - loss: 0.2858 - acc: 0.9133 - val_loss: 0.4412 - val_acc: 0.8587
# Epoch 14/20
# 6640/6680 [============================>.] - ETA: 0s - loss: 0.2810 - acc: 0.9136Epoch 00014: val_loss improved from 0.44117 to 0.44007, saving model to saved_models/xception1.weights.best.hdf5
# 6680/6680 [==============================] - 3s 393us/step - loss: 0.2800 - acc: 0.9139 - val_loss: 0.4401 - val_acc: 0.8587
# Epoch 15/20
# 6600/6680 [============================>.] - ETA: 0s - loss: 0.2751 - acc: 0.9147Epoch 00015: val_loss did not improve
# 6680/6680 [==============================] - 3s 396us/step - loss: 0.2748 - acc: 0.9145 - val_loss: 0.4437 - val_acc: 0.8587
# Epoch 16/20
# 6580/6680 [============================>.] - ETA: 0s - loss: 0.2725 - acc: 0.9143Epoch 00016: val_loss improved from 0.44007 to 0.43616, saving model to saved_models/xception1.weights.best.hdf5
# 6680/6680 [==============================] - 3s 402us/step - loss: 0.2710 - acc: 0.9151 - val_loss: 0.4362 - val_acc: 0.8611
# Epoch 17/20
# 6640/6680 [============================>.] - ETA: 0s - loss: 0.2659 - acc: 0.9170Epoch 00017: val_loss did not improve
# 6680/6680 [==============================] - 3s 377us/step - loss: 0.2653 - acc: 0.9172 - val_loss: 0.4424 - val_acc: 0.8575
# Epoch 18/20
# 6580/6680 [============================>.] - ETA: 0s - loss: 0.2640 - acc: 0.9172Epoch 00018: val_loss did not improve
# 6680/6680 [==============================] - 3s 377us/step - loss: 0.2616 - acc: 0.9181 - val_loss: 0.4450 - val_acc: 0.8611
# Epoch 19/20
# 6620/6680 [============================>.] - ETA: 0s - loss: 0.2573 - acc: 0.9211Epoch 00019: val_loss did not improve
# 6680/6680 [==============================] - 3s 377us/step - loss: 0.2577 - acc: 0.9210 - val_loss: 0.4439 - val_acc: 0.8515
# Epoch 20/20
# 6540/6680 [============================>.] - ETA: 0s - loss: 0.2553 - acc: 0.9219Epoch 00020: val_loss did not improve
# 6680/6680 [==============================] - 2s 371us/step - loss: 0.2541 - acc: 0.9222 - val_loss: 0.4413 - val_acc: 0.8611

# %% [markdown]
# ### (IMPLEMENTATION) Load the Model with the Best Validation Loss

# %%
### Load the model weights with the best validation loss.

model_inception.load_weights('saved_models/inception.weights.best.hdf5')
model_resnet.load_weights('saved_models/resnet.weights.best.hdf5')
model_vgg19.load_weights('saved_models/vgg19.weights.best.hdf5')
model_xception.load_weights('saved_models/xception1.weights.best.hdf5')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline  

# Plot train accuracy
plt.plot(history_inception.history['acc'])
plt.plot(history_resnet.history['acc'])
plt.plot(history_vgg19.history['acc'])
plt.plot(history_xception.history['acc'])
plt.title('Train Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Model Inception Train Acc', 
            'Model Resnet Train Acc', 
            'Model VGG19 Train Acc',
            'Model Xception Train Acc'], loc='upper left')
plt.show()

# Plot validation accuracy
plt.plot(history_inception.history['val_acc'])
plt.plot(history_resnet.history['val_acc'])
plt.plot(history_vgg19.history['val_acc'])
plt.plot(history_xception.history['val_acc'])
plt.title('Validation Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Model Inception Train Acc', 
            'Model Resnet Train Acc', 
            'Model VGG19 Train Acc',
            'Model Xception Train Acc'], loc='upper left')
plt.show()

# Plot validation loss
plt.plot(history_inception.history['val_loss'])
plt.plot(history_resnet.history['val_loss'])
plt.plot(history_vgg19.history['val_loss'])
plt.plot(history_xception.history['val_loss'])
plt.title('Validation Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Model Inception Train Acc', 
            'Model Resnet Train Acc', 
            'Model VGG19 Train Acc',
            'Model Xception Train Acc'], loc='upper left')
plt.show()

# %% [markdown]
# ### (IMPLEMENTATION) Test the Model
#
# Try out your model on the test dataset of dog images. Ensure that your test accuracy is greater than 60%.

# %%
### Calculate classification accuracy on the test dataset.

# %%
model_predictions = [np.argmax(model_inception.predict(np.expand_dims(feature, axis=0))) for feature in test_inception]
test_accuracy = 100*np.sum(np.array(model_predictions)==np.argmax(test_targets, axis=1))/len(model_predictions)

print('Test accuracy: %.4f%%' % test_accuracy)
# Out:
# Test accuracy: 82.1770%

# %%
model_predictions = [np.argmax(model_resnet.predict(np.expand_dims(feature, axis=0))) for feature in test_resnet]
test_accuracy = 100*np.sum(np.array(model_predictions)==np.argmax(test_targets, axis=1))/len(model_predictions)

print('Test accuracy: %.4f%%' % test_accuracy)
# Out:
# Test accuracy: 82.6555%

# %%
model_predictions = [np.argmax(model_vgg19.predict(np.expand_dims(feature, axis=0))) for feature in test_vgg19]
test_accuracy = 100*np.sum(np.array(model_predictions)==np.argmax(test_targets, axis=1))/len(model_predictions)

print('Test accuracy: %.4f%%' % test_accuracy)
# Out:
# Test accuracy: 78.4689%

# %%
model_predictions = [np.argmax(model_xception.predict(np.expand_dims(feature, axis=0))) for feature in test_xception]
test_accuracy = 100*np.sum(np.array(model_predictions)==np.argmax(test_targets, axis=1))/len(model_predictions)

print('Test accuracy: %.4f%%' % test_accuracy)
# Out:
# Test accuracy: 84.5694%

# %% [markdown]
# ### (IMPLEMENTATION) Predict Dog Breed with the Model
#
# Write a function that takes an image path as input and returns the dog breed (`Affenpinscher`, `Afghan_hound`, etc) that is predicted by your model.
#
# Similar to the analogous function in Step 5, your function should have three steps:
# 1. Extract the bottleneck features corresponding to the chosen CNN model.
# 2. Supply the bottleneck features as input to the model to return the predicted vector.  Note that the argmax of this prediction vector gives the index of the predicted dog breed.
# 3. Use the `dog_names` array defined in Step 0 of this notebook to return the corresponding breed.
#
# The functions to extract the bottleneck features can be found in `extract_bottleneck_features.py`, and they have been imported in an earlier code cell.  To obtain the bottleneck features corresponding to your chosen CNN architecture, you need to use the function
#
#     extract_{network}
#
# where `{network}`, in the above filename, should be one of `VGG19`, `Resnet50`, `InceptionV3`, or `Xception`.

# %%
from extract_bottleneck_features import extract_Xception

### Write a function that takes a path to an image as input
### and returns the dog breed that is predicted by the model.

def xception_predict_dog_breed(img_path):
    
    # Predict dog breed
    bottleneck_features = extract_Xception(path_to_tensor(img_path))
    predicted_vector = model_xception.predict(bottleneck_features)[0]
    predicted_dog_id = np.argmax(predicted_vector)

    predicted_dog_breed_name = dog_names[predicted_dog_id]
    
    return predicted_dog_breed_name

print(xception_predict_dog_breed('images/Labrador_retriever_06457.jpg'))
# Out:
# Labrador_retriever

# %% [markdown]
# ---
# <a id='step6'></a>
# ## Step 6: Write your Algorithm
#
# Write an algorithm that accepts a file path to an image and first determines whether the image contains a human, dog, or neither.  Then,
# - if a __dog__ is detected in the image, return the predicted breed.
# - if a __human__ is detected in the image, return the resembling dog breed.
# - if __neither__ is detected in the image, provide output that indicates an error.
#
# You are welcome to write your own functions for detecting humans and dogs in images, but feel free to use the `face_detector` and `dog_detector` functions developed above.  You are __required__ to use your CNN from Step 5 to predict dog breed.
#
# Some sample output for our algorithm is provided below, but feel free to design your own user experience!
#
# ![Sample Human Output](images/sample_human_output.png)
#
#
# ### (IMPLEMENTATION) Write your Algorithm

# %%
### Write your algorithm.
### Feel free to use as many code cells as needed.

def predict_dog_breed(img_path):
    
    num_of_human_faces = face_detector(img_path)
    dog_breed = xception_predict_dog_breed(img_path)
    
    img = cv2.imread(img_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    
    if dog_detector(img_path):
        plt.imshow(img)
        plt.show()
        print("Looks like a " + dog_breed + '.')
        
    elif num_of_human_faces > 0:
        plt.imshow(img)        
        plt.show()
        print("Oh, you are a human!")
        print("Hmmm, funny... You look a little bit like a " + dog_breed + '.')
    
    else:
        plt.imshow(img)
        plt.show()
        print("Error!")

# %% [markdown]
# ---
# <a id='step7'></a>
# ## Step 7: Test Your Algorithm
#
# In this section, you will take your new algorithm for a spin!  What kind of dog does the algorithm think that __you__ look like?  If you have a dog, does it predict your dog's breed accurately?  If you have a cat, does it mistakenly think that your cat is a dog?
#
# ### (IMPLEMENTATION) Test Your Algorithm on Sample Images!
#
# Test your algorithm at least six images on your computer.  Feel free to use any images you like.  Use at least two human and two dog images.
#
# __Question 6:__ Is the output better than you expected :) ?  Or worse :( ?  Provide at least three possible points of improvement for your algorithm.
#
# __Answer:__
# I'd say the algorithm performs as good as I expected. It correctly classified 3/4 dogs.
#
# **Improvements:** <br/>
# - **Augmentation** <br/>
#   I would suggest to play around with data augmentation. Hopefully, this can help us to improve our overall accuracy.
# - **Show classification accuracy to user / Show predicted result only if it exceeds a certain threshold** <br/>
#   Currently, we return a prediction for any kind of image. No matter whether it's the picture of a dog, person, landscape or something else. It, therefore, makes sense to return the output of the final softmax-layer's "winning" tensor since it will tell us something about the confidence in our prediction. <br/>
#   We might also just return predictions for images where the confidence exceeds a certain value.
# - **Add non-dog category** <br/>
#   If we want to improve the accuracy of dog/non-dog images, it might be helpful to add non-dog images to our dataset. Currently, the network is forced to predict a dog breed for every image. By adding a non-dog class it will get the chance to say "there's no dog, hence I cannot predict its dog breed".
# - **Detect dogs in images, extract and classify them** <br/>
# We could come up with an algorithm (e.g. haar features) to find the dogs in an image. Later on, we can "extract" the dog(s) (image regions) and run our classifier exactly on these regions. Of course, training should also be done on the region data on not the whole image. <br/>
# Nicely, this would also allow us to classify multiple dogs in images and we would even know their position in the image.

# %%
## Execute your algorithm from Step 6 on
## at least 6 images on your computer.
## Feel free to use as many code cells as needed.

# Australien Cattle Dog
predict_dog_breed('images/australien_cattle_dog.jpg')

# West Highland White Terrier
predict_dog_breed('images/west-highland-white-terrier.jpg')

# Samoyed
predict_dog_breed('images/samoyed-dogs.jpg')

# Gordon Setter
predict_dog_breed('images/gordon-setter.jpg')

# Me
predict_dog_breed('images/dsoellinger.jpg')

# Dani
predict_dog_breed('images/dreiff.jpg')

# Elbe
predict_dog_breed('images/elbe.jpg')
# Out:
# Looks like a Australian_cattle_dog.
# Looks like a Maltese.
# Looks like a American_eskimo_dog.
# Looks like a Gordon_setter.
# Oh, you are a human!
# Hmmm, funny... You look a little bit like a Dachshund.
# Oh, you are a human!
# Hmmm, funny... You look a little bit like a Dachshund.

# %% [markdown]
# # Please download your notebook to submit
